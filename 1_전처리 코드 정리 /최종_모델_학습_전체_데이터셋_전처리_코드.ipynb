# %% [markdown]
# ### 하위폴더 파일 한곳으로 모으기

# %%
import os
import shutil

def copy_files_to_destination(source_folder, destination_folder):
    # 소스 폴더의 모든 하위 폴더와 그 하위 폴더를 순회합니다.
    for root, dirs, files in os.walk(source_folder):
        for file in files:
            source_file = os.path.join(root, file)
            destination_file = os.path.join(destination_folder, file)

            # 파일 이름이 겹치지 않도록 처리합니다.
            counter = 1
            while os.path.exists(destination_file):
                file_name, file_extension = os.path.splitext(file)
                new_file_name = f"{file_name}_{counter}{file_extension}"
                destination_file = os.path.join(destination_folder, new_file_name)
                counter += 1

            # 파일을 목적지 폴더로 복사합니다.
            shutil.copy2(source_file, destination_file)
            print(f'Copied: {source_file} to {destination_file}')

# 소스 폴더와 목적지 폴더의 경로를 입력합니다.
source_folder = r"C:\Users\LMK\Desktop\도로로드마크"  # 소스 폴더의 경로
destination_folder = r"C:\Users\LMK\Desktop\도로로드마크_전처리수합"  # 목적지 폴더의 경로

# 목적지 폴더가 존재하지 않으면 생성합니다.
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# 파일을 복사합니다.
copy_files_to_destination(source_folder, destination_folder)

# %% [markdown]
# ### categori_id 통계 및 분류

# %%
# json파일이 각각 존재
import os
import json
import shutil
from collections import defaultdict


def count_category_ids_in_jsons_and_copy(source_folder, output_folder):
    category_counts = defaultdict(int)
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for root, dirs, files in os.walk(source_folder):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        data = json.load(f)
                        for image_data in data.values():
                            if 'regions' in image_data:
                                for region_key, region in image_data['regions'].items():
                                    if 'region_attributes' in region:
                                        category_id = region['region_attributes'].get('label')
                                        if category_id is not None:
                                            category_counts[category_id] += 1

                                            category_folder = os.path.join(output_folder, f"category_{category_id}")
                                            if not os.path.exists(category_folder):
                                                os.makedirs(category_folder)

                                            original_image_filename = image_data.get("filename")
                                            if original_image_filename:
                                                original_image_path = os.path.join(root, original_image_filename)
                                                if os.path.exists(original_image_path):
                                                    destination_file_path = os.path.join(category_folder, original_image_filename)
                                                    shutil.copy(original_image_path, destination_file_path)
                                                    print(f'Copied: {original_image_path} to {destination_file_path}')
                                                else:
                                                    print(f"Image file {original_image_path} does not exist")
                                            else:
                                                print("Filename not found in JSON")
                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
    return dict(category_counts)

# 기타 코드는 동일...
def save_results_to_file(results, output_file):
    with open(output_file, 'w', encoding='utf-8') as f:
        for category_id, count in results.items():
            f.write(f"Category ID {category_id}: {count} file(s)\n")

# 소스 폴더 경로를 설정합니다.
source_folder = r"C:\Users\LMK\Desktop\mult\multi_img\train"# 소스 폴더의 경로를 입력하세요.
output_folder = r"C:\Users\LMK\Desktop\output_multi_train"  # 결과를 저장할 폴더 경로를 입력하세요.
output_file = r"C:\Users\LMK\Desktop\category_counts_multi_train.txt"  # 결과를 저장할 파일 경로를 입력하세요.

# 카테고리 ID 갯수를 세고 결과를 출력하고 파일을 복사합니다.
category_counts = count_category_ids_in_jsons_and_copy(source_folder, output_folder)

# 결과를 파일에 저장합니다.
save_results_to_file(category_counts, output_file)

# 결과를 출력합니다.
for category_id, count in category_counts.items():
    print(f"Category ID {category_id}: {count} file(s)")

# %%
# 하나의 json으로 통합

import os
import json
import shutil
from collections import defaultdict

def count_category_ids_in_single_json_and_copy(json_file, source_folder, output_folder):
    category_counts = defaultdict(int)
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    try:
        with open(json_file, 'r', encoding='utf-8') as f:
            data = json.load(f)
            for image_data in data.values():
                if 'regions' in image_data:
                    for region_key, region in image_data['regions'].items():
                        if 'region_attributes' in region:
                            category_id = region['region_attributes'].get('label')
                            if category_id is not None:
                                category_counts[category_id] += 1

                                category_folder = os.path.join(output_folder, f"category_{category_id}")
                                if not os.path.exists(category_folder):
                                    os.makedirs(category_folder)

                                original_image_filename = image_data.get("filename")
                                if original_image_filename:
                                    original_image_path = os.path.join(source_folder, original_image_filename)
                                    if os.path.exists(original_image_path):
                                        destination_file_path = os.path.join(category_folder, original_image_filename)
                                        shutil.copy(original_image_path, destination_file_path)
                                        print(f'Copied: {original_image_path} to {destination_file_path}')
                                    else:
                                        print(f"Image file {original_image_path} does not exist")
                                else:
                                    print("Filename not found in JSON")
    except Exception as e:
        print(f"Error reading {json_file}: {e}")

    return dict(category_counts)

def save_results_to_file(results, output_file):
    with open(output_file, 'w', encoding='utf-8') as f:
        for category_id, count in results.items():
            f.write(f"Category ID {category_id}: {count} file(s)\n")

# JSON 파일과 폴더 경로를 설정합니다.
json_file = r"C:\Users\LMK\Desktop\mult\multi_img\val\val_input.json"  # JSON 파일 경로를 입력하세요.
source_folder = r"C:\Users\LMK\Desktop\mult\multi_img\val"  # 이미지 파일이 있는 폴더 경로를 입력하세요.
output_folder = r"C:\Users\LMK\Desktop\output_multi_val"  # 결과를 저장할 폴더 경로를 입력하세요.
output_file = r"C:\Users\LMK\Desktop\category_counts_multi_val.txt"  # 결과를 저장할 파일 경로를 입력하세요.

# 카테고리 ID 갯수를 세고 결과를 출력하고 파일을 복사합니다.
category_counts = count_category_ids_in_single_json_and_copy(json_file, source_folder, output_folder)

# 결과를 파일에 저장합니다.
save_results_to_file(category_counts, output_file)

# 결과를 출력합니다.
for category_id, count in category_counts.items():
    print(f"Category ID {category_id}: {count} file(s)")

# %% [markdown]
# ### json 파일 불러오기(원본)

# %%
import os
import shutil

# 이미지 폴더의 상위 경로 설정
base_image_folder = r"C:\Users\LMK\Desktop\output"
json_source_folder = r"E:\087.도로 로드마크 인식을 위한 주행 영상 데이터\01.데이터\1.Training\라벨링데이터\2D_JSON"

# 이미지 파일 확장자 목록 (필요에 따라 확장자를 추가)
image_extensions = ['.jpg', '.jpeg', '.png', '.bmp']

# 상위 이미지 폴더를 스캔하여 모든 하위 폴더를 검색
for root, dirs, files in os.walk(base_image_folder):
    for file in files:
        # 이미지 파일인지 확인
        if os.path.splitext(file)[1].lower() in image_extensions:
            image_name_without_extension = os.path.splitext(file)[0]
            json_file_name = image_name_without_extension + '.json'
            json_source_path = os.path.join(json_source_folder, json_file_name)
            json_target_path = os.path.join(root, json_file_name)  # 동일한 폴더로 복사

            # JSON 파일이 소스 폴더에 있는지 확인
            if os.path.exists(json_source_path):
                shutil.copy(json_source_path, json_target_path)  # JSON 파일을 동일한 폴더로 복사
               # print(f"Copied: {json_source_path} -> {json_target_path}")
            else:
                print(f"JSON file not found for image: {file}")

# %% [markdown]
# ### 필요클래스 추리기

# %%
import os
import json

# 수정할 코드 목록
code_to_detect = [389, 391, 402, 403, 412, 432]

    # 389: 주차금지 - seg
    # 391: 정차, 주차금지 - seg
    # 402: 속도제한 어린이 보호 구역 - bbox
    # 403: 어린이 보호 구역 - bbox
    # 412: 횡단보도 - seg
    # 432: 정차금지지대 -seg

    # 클래스별 개수 찾기


# 상위 폴더 경로 설정
base_folder = r"C:\Users\LMK\Desktop\6CLASS" # 이미지 및 JSON 파일이 들어있는 상위 폴더의 경로

# 폴더 탐색
for root, dirs, files in os.walk(base_folder):
    for file in files:
        if file.endswith('.json'):
            json_file_path = os.path.join(root, file)
            with open(json_file_path, 'r', encoding='utf-8') as json_file:
                data = json.load(json_file)

            # 'categories' 항목 제거
            if 'categories' in data:
                del data['categories']

            # 'images' 항목 수정
            if 'images' in data:
                for image in data['images']:
                    image_keys_to_keep = {'filename', 'width', 'height'}
                    keys_to_remove = set(image.keys()) - image_keys_to_keep
                    for key in keys_to_remove:
                        del image[key]

            # 'annotations' 항목 수정
            if 'annotations' in data:
                data['annotations'] = [annotation for annotation in data['annotations'] if annotation['category_id'] in code_to_detect]

            # 수정된 JSON 파일 저장
            with open(json_file_path, 'w', encoding='utf-8') as json_file:
                json.dump(data, json_file, indent=4, ensure_ascii=False)
            #print(f"Updated {json_file_path}")

# %% [markdown]
# ### json 수정 -> 402, 403제외하고 bbox 제거

# %%
import os
import json

# 상위 폴더 경로 설정
base_folder = r"C:\Users\LMK\Desktop\6class_merge"  # JSON 파일이 들어있는 상위 폴더

# 제외할 카테고리 ID 설정
categories_to_exclude = [402, 403]

# 폴더 탐색
for root, dirs, files in os.walk(base_folder):
    for file in files:
        if file.endswith('.json'):
            json_file_path = os.path.join(root, file)

            try:
                # JSON 파일 읽기
                with open(json_file_path, 'r', encoding='utf-8') as json_file:
                    data = json.load(json_file)

                # 'annotations' 항목 수정
                for annotation in data.get('annotations', []):
                    category_id = annotation.get('category_id', 'Unknown')
                    if category_id not in categories_to_exclude:
                        # bbox 제거
                        if 'bbox' in annotation:
                            del annotation['bbox']

                # 수정된 JSON 파일 저장
                with open(json_file_path, 'w', encoding='utf-8') as json_file:
                    json.dump(data, json_file, indent=4, ensure_ascii=False)

                print(f"Processed {json_file_path}")

            except Exception as e:
                print(f"Error processing file {json_file_path}: {e}")

# %% [markdown]
# ### class 이름 변경

# %%
import os
import json

# 상위 폴더 경로 설정
base_folder = r"C:\Users\LMK\Desktop\6class_merge"  # JSON 파일이 들어있는 상위 폴더

# 카테고리 아이디를 영어 이름으로 매핑
category_mapping = {
    402: 'Road_Speed_Limit_in_School_Zone',  # 어린이 보호 구역 속도 제한
    403: 'Road_School_Zone',                 # 어린이 보호 구역
    412: 'Crosswalk',                        # 횡단보도
    432: 'Road_No_Stopping_Zone',            # 정차 금지
    389: 'Road_No_Parking',                  # 주차 금지
    391: 'Road_No_Stopping_or_Parking'       # 정차 및 주차 금지
}

# 폴더 탐색
for root, dirs, files in os.walk(base_folder):
    for file in files:
        if file.endswith('.json'):
            json_file_path = os.path.join(root, file)

            try:
                # JSON 파일 읽기
                with open(json_file_path, 'r', encoding='utf-8') as json_file:
                    data = json.load(json_file)

                # 'annotations' 항목 수정
                for annotation in data.get('annotations', []):
                    category_id = annotation.get('category_id', None)
                    if category_id in category_mapping:
                        annotation['category_id'] = category_mapping[category_id]

                # 수정된 JSON 파일 저장
                with open(json_file_path, 'w', encoding='utf-8') as json_file:
                    json.dump(data, json_file, indent=4, ensure_ascii=False)

                print(f"Processed {json_file_path}")

            except Exception as e:
                print(f"Error processing file {json_file_path}: {e}")

# %% [markdown]
# ### 통계

# %%
import os
import json
from collections import defaultdict

# 상위 폴더 경로 설정
base_folder = r"C:\Users\LMK\Desktop\6class_merge"  # JSON 파일이 들어있는 상위 폴더
stats_file = r"C:\Users\LMK\Desktop\category_stats.json"  # 통계 파일을 저장할 경로

# 카테고리 매핑 설정
category_mapping = {
    'Road_Speed_Limit_in_School_Zone': '어린이 보호 구역 속도 제한',  # 매핑 설명 (한국어 설명)
    'Road_School_Zone': '어린이 보호 구역',
    'Crosswalk': '횡단보도',
    'Road_No_Stopping_Zone': '정차 금지',
    'Road_No_Parking': '주차 금지',
    'Road_No_Stopping_or_Parking': '정차 및 주차 금지'
}

# 카테고리별 통계 초기화
category_stats = defaultdict(int)

# 폴더 탐색
for root, dirs, files in os.walk(base_folder):
    for file in files:
        if file.endswith('.json'):
            json_file_path = os.path.join(root, file)

            try:
                # JSON 파일 읽기
                with open(json_file_path, 'r', encoding='utf-8') as json_file:
                    data = json.load(json_file)

                # JSON 파일 형식 및 데이터 확인
                if 'annotations' not in data:
                    print(f"Annotations key not found in {json_file_path}")
                    continue

                annotations = data['annotations']
                if not annotations:
                    print(f"No annotations found in {json_file_path}")
                    continue

                # 'annotations' 항목에서 카테고리 아이디를 카운트
                for annotation in annotations:
                    category_id = annotation.get('category_id')
                    if category_id is None:
                        print(f"Category ID missing in {json_file_path}")
                        continue

                    if category_id in category_mapping:
                        category_stats[category_id] += 1
                    else:
                        print(f"Unknown category ID {category_id} in {json_file_path}")

            except Exception as e:
                print(f"Error processing file {json_file_path}: {e}")

# 카테고리 이름을 추가하여 통계 생성
category_stats_with_names = {
    category_mapping[cat_id]: count for cat_id, count in category_stats.items()
}

# 통계 결과를 JSON 파일로 저장
with open(stats_file, 'w', encoding='utf-8') as json_file:
    json.dump(category_stats_with_names, json_file, indent=4, ensure_ascii=False)

print(f"Category statistics saved to {stats_file}")

# %% [markdown]
# ### coco?-> via 변환

# %%
import os
import json

def convert_to_via_format(input_folder, output_file):
    via_data = {}

    for root, dirs, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.json'):
                json_file_path = os.path.join(root, file)

                try:
                    with open(json_file_path, 'r', encoding='utf-8') as json_file:
                        data = json.load(json_file)

                    # 이미지 파일 정보
                    image_info = data['images'][0]
                    filename = image_info['filename']
                    size = os.path.getsize(os.path.join(root, filename))
                    image_id = image_info.get('id', filename)

                    via_data[filename] = {
                        "filename": filename,
                        "size": size,
                        "regions": {},
                        "file_attributes": {}
                    }

                    # 객체 정보
                    regions = {}
                    for idx, annotation in enumerate(data['annotations']):
                        category_id = annotation.get('category_id', 'Unknown')
                        shape_type = 'polygon'
                        all_points_x = []
                        all_points_y = []

                        # Segmentation 처리
                        if 'segmentation' in annotation:
                            points = annotation['segmentation'][0]
                            for i in range(0, len(points), 2):
                                all_points_x.append(int(points[i]))
                                all_points_y.append(int(points[i+1]))

                        # Polyline 처리 (폴리곤으로 변환)
                        elif 'polyline' in annotation:
                            points = annotation['polyline'][0]
                            for i in range(0, len(points), 2):
                                all_points_x.append(int(points[i]))
                                all_points_y.append(int(points[i+1]))
                            # 첫 번째 점을 추가하여 폴리곤으로 변환
                            all_points_x.append(all_points_x[0])
                            all_points_y.append(all_points_y[0])

                        # BBox 처리 (폴리곤으로 변환)
                        elif 'bbox' in annotation:
                            x, y, width, height = annotation['bbox']
                            all_points_x = [int(x), int(x + width), int(x + width), int(x), int(x)]
                            all_points_y = [int(y), int(y), int(y + height), int(y + height), int(y)]

                        # Region 구성
                        regions[str(idx)] = {
                            "shape_attributes": {
                                "name": shape_type,
                                "all_points_x": all_points_x,
                                "all_points_y": all_points_y
                            },
                            "region_attributes": {
                                "category": category_id
                            }
                        }

                    via_data[filename]["regions"] = regions

                except Exception as e:
                    print(f"Error processing file {json_file_path}: {e}")

    # VIA 형식의 JSON 파일 저장
    with open(output_file, 'w', encoding='utf-8') as json_file:
        json.dump(via_data, json_file, indent=4, ensure_ascii=False)

    print(f"VIA formatted data saved to {output_file}")

# 사용 예시
input_folder = r"C:\Users\LMK\Desktop\6class_merge"
output_file = r"C:\Users\LMK\Desktop\via_format1.json"
convert_to_via_format(input_folder, output_file)

# %%
#폴리라인 포함 -> json병합


import os
import json

def convert_to_via_format(input_folder, output_file):
    via_data = {}

    for root, dirs, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.json'):
                json_file_path = os.path.join(root, file)

                try:
                    with open(json_file_path, 'r', encoding='utf-8') as json_file:
                        data = json.load(json_file)

                    # 이미지 파일 정보
                    image_info = data['images'][0]
                    filename = image_info['filename']
                    size = os.path.getsize(os.path.join(root, filename))
                    image_id = image_info.get('id', filename)

                    via_data[filename] = {
                        "filename": filename,
                        "size": size,
                        "regions": {},
                        "file_attributes": {}
                    }

                    # 객체 정보
                    regions = {}
                    for idx, annotation in enumerate(data['annotations']):
                        category_id = annotation.get('label', 'Unknown')
                        all_points_x = []
                        all_points_y = []

                        # Segmentation 처리 (폴리곤)
                        if 'segmentation' in annotation:
                            shape_type = 'polygon'
                            points = annotation['segmentation'][0]
                            for i in range(0, len(points), 2):
                                all_points_x.append(int(points[i]))
                                all_points_y.append(int(points[i + 1]))
                            # Ensure the polygon is closed
                            if all_points_x[-1] != all_points_x[0] or all_points_y[-1] != all_points_y[0]:
                                all_points_x.append(all_points_x[0])
                                all_points_y.append(all_points_y[0])

                        # BBox 처리 (폴리곤으로 변환)
                        elif 'bbox' in annotation:
                            shape_type = 'polygon'
                            x, y, width, height = annotation['bbox']
                            all_points_x = [int(x), int(x + width), int(x + width), int(x), int(x)]
                            all_points_y = [int(y), int(y), int(y + height), int(y + height), int(y)]
                            # Ensure the polygon is closed
                            if all_points_x[-1] != all_points_x[0] or all_points_y[-1] != all_points_y[0]:
                                all_points_x.append(all_points_x[0])
                                all_points_y.append(all_points_y[0])

                        # 폴리라인 처리
                        elif 'polyline' in annotation:
                            shape_type = 'polyline'
                            points = annotation['polyline']
                            if isinstance(points[0], list):
                                # 여러 개의 polyline이 있는 경우
                                for sublist in points:
                                    for i in range(0, len(sublist), 2):
                                        all_points_x.append(int(sublist[i]))
                                        all_points_y.append(int(sublist[i + 1]))
                            else:
                                # 단일 polyline인 경우
                                for i in range(0, len(points), 2):
                                    all_points_x.append(int(points[i]))
                                    all_points_y.append(int(points[i + 1]))

                        # Region 구성
                        regions[str(idx)] = {
                            "shape_attributes": {
                                "name": shape_type,
                                "all_points_x": all_points_x,
                                "all_points_y": all_points_y
                            },
                            "region_attributes": {
                                "category": category_id
                            }
                        }

                    via_data[filename]["regions"] = regions

                except Exception as e:
                    print(f"Error processing file {json_file_path}: {e}")

    # VIA 형식의 JSON 파일 저장
    with open(output_file, 'w', encoding='utf-8') as json_file:
        json.dump(via_data, json_file, indent=4, ensure_ascii=False)

    print(f"VIA formatted data saved to {output_file}")

# 사용 예시
input_folder = r"C:\Users\LMK\Desktop\어린이보호구역표지판"
output_file = r"C:\Users\LMK\Desktop\new_stats\school_zone.stats"
convert_to_via_format(input_folder, output_file)

# %% [markdown]
# ### via 여러개 -> 한개의 json으로 합병

# %%
#구분자가 있을떄

import json
import os

# JSON 파일이 있는 디렉토리 경로
json_dir = r"C:\Users\LMK\Desktop\new_stats\merge" # 경로를 파일들이 저장된 위치로 변경하세요

# 결합된 데이터를 저장할 빈 딕셔너리 초기화
combined_data = {}

# 디렉토리 내 모든 파일을 순회
for filename in os.listdir(json_dir):
    if filename.endswith('.json'):
        filepath = os.path.join(json_dir, filename)
        with open(filepath, 'r', encoding='utf-8') as file:
            data = json.load(file)
            # 파일 이름을 키로 사용하여 데이터 추가
            combined_data[filename] = data

# 결합된 데이터를 새로운 JSON 파일로 출력
output_filepath = r"C:\Users\LMK\Desktop\new_stats\merge\new_merge_10.json" # 저장할 경로를 업데이트하세요
with open(output_filepath, 'w', encoding='utf-8') as outfile:
    json.dump(combined_data, outfile, indent=4, ensure_ascii=False)

print(f"결합된 JSON 데이터가 {output_filepath}에 저장되었습니다.")

# %%
##구분자 없을때 일단 파일명으로 -> 추후에 메모장에서 모두바꾸기할것

import os
import json

def merge_via_json_files(input_folder, output_file):
    merged_via_data = {}
    duplicate_files = {}

    for root, dirs, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.json'):
                json_file_path = os.path.join(root, file)

                try:
                    with open(json_file_path, 'r', encoding='utf-8') as json_file:
                        data = json.load(json_file)

                        # 데이터가 dict인지 확인
                        if not isinstance(data, dict):
                            print(f"Warning: File {json_file_path} does not contain a valid JSON object.")
                            continue

                        for original_filename, image_data in data.items():
                            # 파일명 구분자를 JSON 파일명으로 변경
                            filename = os.path.basename(original_filename)

                            if filename in merged_via_data:
                                # 중복된 파일명 처리
                                if filename not in duplicate_files:
                                    duplicate_files[filename] = []
                                duplicate_files[filename].append(json_file_path)
                            else:
                                if not isinstance(image_data, dict):
                                    print(f"Warning: Data for {filename} in {json_file_path} is not a valid dictionary.")
                                    continue

                                # 정해진 형식에 맞추어 데이터 추가
                                merged_via_data[filename] = {
                                    "filename": image_data.get("filename", filename),
                                    "size": image_data.get("size", 0),
                                    "regions": image_data.get("regions", {}),
                                    "file_attributes": image_data.get("file_attributes", {})
                                }

                except json.JSONDecodeError as jde:
                    print(f"JSON decode error in file {json_file_path}: {jde}")
                except Exception as e:
                    print(f"Error processing file {json_file_path}: {e}")

    # 중복된 파일명 출력
    if duplicate_files:
        print("중복된 파일명이 발견되었습니다. 첫 번째 파일만 병합됩니다:")
        for filename, paths in duplicate_files.items():
            print(f"파일명: {filename}")
            for path in paths:
                print(f"  - 경로: {path}")

    # 병합된 VIA 형식의 JSON 파일 저장
    with open(output_file, 'w', encoding='utf-8') as json_file:
        json.dump(merged_via_data, json_file, indent=4, ensure_ascii=False)

    print(f"VIA formatted data merged and saved to {output_file}")

# 사용 예시
input_folder = r"C:\Users\LMK\Desktop\어린이보호구역표지판"
output_file = r"C:\Users\LMK\Desktop\new_stats\merged_school_zone.json"
merge_via_json_files(input_folder, output_file)

# %%
import os
import json
from collections import defaultdict

# 입력 및 출력 파일 경로 설정
input_via_file =  r"C:\Users\LMK\Desktop\merge_10class\merged_class_10_updated.json" # 변환된 VIA 파일 경로
stats_output_file =  r"C:\Users\LMK\Desktop\merge_10class\merged_class_10_updated_stats.json"  # 통계 결과를 저장할 경로

# 카테고리별 통계 초기화
category_stats = defaultdict(int)
total_images = 0

# VIA 파일 읽기
try:
    with open(input_via_file, 'r', encoding='utf-8') as via_file:
        via_data = json.load(via_file)

    # 총 이미지 수 계산
    total_images = len(via_data)

    # 카테고리별 통계 계산
    for image_data in via_data.values():
        regions = image_data.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('label', 'Unknown')  ##label과 CATEGORY
            category_stats[category] += 1

    # 통계 결과 출력
    print(f"Total number of images: {total_images}")
    print("Category statistics:")
    for category, count in category_stats.items():
        print(f"{category}: {count}")

    # 통계 결과를 JSON 파일로 저장
    with open(stats_output_file, 'w', encoding='utf-8') as stats_file:
        json.dump({
            "total_images": total_images,
            "category_statistics": category_stats
        }, stats_file, indent=4, ensure_ascii=False)

    print(f"Statistics saved to {stats_output_file}")

except Exception as e:
    print(f"Error processing VIA file: {e}")
# Out:
# Total number of images: 16276
# Category statistics:
# no_parking: 4307
# school_zone: 892
# stop: 2532
# fire_hydrant: 1524
# Road_No_Stopping_Zone: 565
# Road_No_Stopping_or_Parking: 8975
# Crosswalk: 3924
# Road_No_Parking: 3407
# Road_Speed_Limit_in_School_Zone: 1506
# Road_School_Zone: 2050
# Statistics saved to C:\Users\LMK\Desktop\merge_10class\merged_class_10_updated_stats.json

# %% [markdown]
# ### 시각화

# %%
#bbox, seg, polyline 확인용

import os
import json
import cv2
import numpy as np

# 상위 폴더 경로 설정
base_folder = r"C:\Users\LMK\Desktop\output"  # 이미지와 JSON 파일이 들어있는 상위 폴더
output_folder = r"C:\Users\LMK\Desktop\output_visual"  # 시각화된 이미지를 저장할 폴더

# 색상 설정
color_bbox = (0, 255, 0)  # 녹색
color_segmentation = (255, 0, 0)  # 빨강색
color_polyline = (0, 0, 255)  # 파란색
font_color = (255, 255, 255)  # 흰색
font_scale = 0.5
thickness = 2
font = cv2.FONT_HERSHEY_SIMPLEX

# 폴더 탐색
for root, dirs, files in os.walk(base_folder):
    for file in files:
        if file.endswith('.json'):
            try:
                json_file_path = os.path.join(root, file)

                # 이미지 파일 경로 설정
                image_filename = file.replace('.json', '.png')
                image_file_path = os.path.join(root, image_filename)

                # 이미지가 존재하는지 확인
                if not os.path.exists(image_file_path):
                    print(f"Image file not found for {json_file_path}")
                    continue

                # JSON 파일 읽기
                try:
                    with open(json_file_path, 'r', encoding='utf-8') as json_file:
                        data = json.load(json_file)
                except Exception as e:
                    print(f"Error reading JSON file {json_file_path}: {e}")
                    continue

                # 이미지 읽기
                try:
                    image = cv2.imread(image_file_path)
                    if image is None:
                        raise ValueError("Image is None")
                except Exception as e:
                    print(f"Error reading image {image_file_path}: {e}")
                    continue

                # 시각화 작업
                try:
                    for annotation in data.get('annotations', []):
                        category_id = annotation.get('category_id', 'Unknown')
                        text = f"Class ID: {category_id}"

                        # bbox 시각화
                        bbox = annotation.get('bbox', [])
                        if bbox:
                            x, y, width, height = bbox
                            start_point = (int(x), int(y))
                            end_point = (int(x + width), int(y + height))
                            image = cv2.rectangle(image, start_point, end_point, color_bbox, thickness)  # 녹색
                            cv2.putText(image, f"bbox: {bbox}", (int(x), int(y) - 10), font, font_scale, font_color, thickness, cv2.LINE_AA)

                        # segmentation 시각화
                        segmentation = annotation.get('segmentation', [])
                        if segmentation:
                            points = np.array(segmentation[0], dtype=np.int32).reshape((-1, 1, 2))
                            image = cv2.polylines(image, [points], isClosed=True, color=color_segmentation, thickness=thickness)  # 빨강색
                            cv2.putText(image, "segmentation", (int(points[0][0][0]), int(points[0][0][1]) - 10), font, font_scale, font_color, thickness, cv2.LINE_AA)

                        # polyline 시각화 및 폴리곤 변환
                        polyline = annotation.get('polyline', [])
                        if polyline:
                            polyline_points = np.array(polyline[0], dtype=np.int32).reshape((-1, 2))
                            polyline_polygon_points = np.vstack((polyline_points, polyline_points[0]))  # 첫 번째 점을 추가하여 폴리곤으로 변환
                            image = cv2.polylines(image, [polyline_polygon_points], isClosed=True, color=color_polyline, thickness=thickness)  # 파란색
                            cv2.putText(image, "polyline", (int(polyline_points[0][0]), int(polyline_points[0][1]) - 10), font, font_scale, font_color, thickness, cv2.LINE_AA)

                        # 클래스 아이디 표시
                        x_pos = int(bbox[0]) if bbox else int(points[0][0][0]) if segmentation else int(polyline_points[0][0])
                        y_pos = int(bbox[1]) if bbox else int(points[0][0][1]) if segmentation else int(polyline_points[0][1])
                        cv2.putText(image, text, (x_pos, y_pos - 20), font, font_scale, font_color, thickness, cv2.LINE_AA)

                        # 각 클래스별 아웃풋 폴더 경로 설정
                        class_output_folder = os.path.join(output_folder, str(category_id))
                        os.makedirs(class_output_folder, exist_ok=True)

                        # 결과 저장
                        output_image_path = os.path.join(class_output_folder, f"{os.path.splitext(file)[0]}.png")
                        cv2.imwrite(output_image_path, image)
                        print(f"Saved visualized image to {output_image_path}")
                except Exception as e:
                    print(f"Error processing annotation in {json_file_path}: {e}")

            except Exception as e:
                print(f"Error processing file {json_file_path}: {e}")

# %%
#via 한개로 시각

import os
import json
import cv2
import numpy as np

# 입력 및 출력 경로 설정
via_file = r"C:\Users\LMK\Desktop\via_format_polyline.json"  # 변환된 VIA 파일 경로
image_folder = r"C:\Users\LMK\Desktop\6class_merge"  # 원본 이미지 파일이 들어있는 폴더
output_folder = r"C:\Users\LMK\Desktop\visual_image_6merge_polyline"  # 시각화된 이미지를 저장할 폴더

# 색상 및 폰트 설정
color_mapping = {
    'Road_Speed_Limit_in_School_Zone': (0, 255, 0),  # 녹색
    'Road_School_Zone': (255, 0, 0),                 # 빨강색
    'Crosswalk': (0, 0, 255),                        # 파란색
    'Road_No_Stopping_Zone': (255, 255, 0),          # 노랑색
    'Road_No_Parking': (255, 0, 255),                # 보라색
    'Road_No_Stopping_or_Parking': (0, 255, 255)     # 청록색
}
font_color = (255, 255, 255)  # 흰색
font_scale = 0.5
thickness = 2
font = cv2.FONT_HERSHEY_SIMPLEX

# VIA 파일 읽기
try:
    with open(via_file, 'r', encoding='utf-8') as via_json_file:
        via_data = json.load(via_json_file)

    # 폴더 생성
    os.makedirs(output_folder, exist_ok=True)

    # 이미지 파일 탐색 및 시각화
    for image_key, image_data in via_data.items():
        image_path = os.path.join(image_folder, image_key)
        if not os.path.exists(image_path):
            print(f"Image file not found: {image_path}")
            continue

        # 이미지 읽기
        image = cv2.imread(image_path)
        if image is None:
            print(f"Failed to read image: {image_path}")
            continue

        # 객체 시각화
        regions = image_data.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('category', 'Unknown')
            if category not in color_mapping:
                print(f"Unknown category: {category}")
                continue

            color = color_mapping[category]
            all_points_x = region['shape_attributes'].get('all_points_x', [])
            all_points_y = region['shape_attributes'].get('all_points_y', [])

            if all_points_x and all_points_y and len(all_points_x) == len(all_points_y):
                points = np.array([[x, y] for x, y in zip(all_points_x, all_points_y)], dtype=np.int32)
                points = points.reshape((-1, 1, 2))

                # 폴리곤 그리기
                image = cv2.polylines(image, [points], isClosed=False, color=color, thickness=thickness)

                # 텍스트 표시 (카테고리 이름)
                text_position = (all_points_x[0], all_points_y[0] - 10)
                cv2.putText(image, category, text_position, font, font_scale, font_color, thickness, cv2.LINE_AA)

        # 결과 이미지 저장
        output_image_path = os.path.join(output_folder, image_key)
        cv2.imwrite(output_image_path, image)
        print(f"Saved visualized image to {output_image_path}")

except Exception as e:
    print(f"Error processing VIA file: {e}")

# %% [markdown]
# ### train/val 나누기. via.json으로 나누기

# %%
import os
import json
import random
from collections import defaultdict

# 설정 경로
via_file = r"C:\Users\LMK\Desktop\via_format_polyline.json"  # VIA 파일 경로
output_folder = r"C:\Users\LMK\Desktop\dataset_split2"  # 데이터셋 분할 결과 저장 폴더

# 클래스별 목표 개수
target_train_size = 250
target_val_size = 100

# 클래스별 최대 개수 설정 (실제 데이터 개수 고려)
class_target_sizes = {
    'Road_No_Stopping_or_Parking': {'train': target_train_size, 'val': target_val_size},
    'Crosswalk': {'train': target_train_size, 'val': target_val_size},
    'Road_Speed_Limit_in_School_Zone': {'train': target_train_size, 'val': target_val_size},
    'Road_School_Zone': {'train': target_train_size, 'val': target_val_size},
    'Road_No_Stopping_Zone': {'train': 450, 'val': 100},
    'Road_No_Parking': {'train': target_train_size, 'val': target_val_size}
}

# 클래스별 이미지 목록
class_images = defaultdict(list)

# VIA 파일 읽기
try:
    with open(via_file, 'r', encoding='utf-8') as f:
        via_data = json.load(f)

    # 이미지별 클래스 수집
    for image_id, image_info in via_data.items():
        regions = image_info.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('category')
            if category:
                class_images[category].append(image_id)
except Exception as e:
    print(f"Error reading VIA file: {e}")

# train과 val 세트
train_set = set()
val_set = set()

# 클래스별로 train과 val로 나누기
for category, images in class_images.items():
    random.shuffle(images)
    target_sizes = class_target_sizes.get(category, {'train': target_train_size, 'val': target_val_size})
    train_count = target_sizes['train']
    val_count = target_sizes['val']

    # 현재 카테고리에서 사용될 이미지 필터링
    filtered_images = [img for img in images if img not in train_set and img not in val_set]

    # train과 val 세트로 나누기
    train_images = filtered_images[:train_count]
    val_images = filtered_images[train_count:train_count + val_count]

    train_set.update(train_images)
    val_set.update(val_images)

# 중복 제거
val_set.difference_update(train_set)  # train_set과 중복된 항목 제거

# 결과 출력
print(f"Train set size: {len(train_set)}")
print(f"Validation set size: {len(val_set)}")

# 분할된 데이터셋 저장
os.makedirs(output_folder, exist_ok=True)

train_file = os.path.join(output_folder, 'train.json')
val_file = os.path.join(output_folder, 'val.json')

# 저장할 데이터 생성
train_data = {image_id: via_data[image_id] for image_id in train_set}
val_data = {image_id: via_data[image_id] for image_id in val_set}

try:
    with open(train_file, 'w', encoding='utf-8') as f:
        json.dump(train_data, f, indent=4, ensure_ascii=False)

    with open(val_file, 'w', encoding='utf-8') as f:
        json.dump(val_data, f, indent=4, ensure_ascii=False)

    print(f"Train set saved to {train_file}")
    print(f"Validation set saved to {val_file}")
except Exception as e:
    print(f"Error saving dataset: {e}")
# Out:
# Train set size: 0
# Validation set size: 0
# Train set saved to C:\Users\LMK\Desktop\merge_10class\train.json
# Validation set saved to C:\Users\LMK\Desktop\merge_10class\val.json

# %%
import os
import json

# JSON 파일 경로
json_file_path = r"C:\Users\LMK\Desktop\merge_10class\merged_class_10_updated.json"
# 원본 이미지 폴더 경로
image_folder_path = r"C:\Users\LMK\Desktop\merge"

# JSON 파일 읽기
with open(json_file_path, 'r') as json_file:
    json_data = json.load(json_file)
    # JSON 데이터가 via 형식의 딕셔너리 구조인 경우
    json_image_files = list(json_data.keys())

# 원본 이미지 목록 가져오기
image_files = [file for file in os.listdir(image_folder_path) if file.endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif'))]

# JSON에 있지만 원본 이미지 폴더에 없는 파일 찾기
missing_in_images = [file for file in json_image_files if file not in image_files]

# 원본 이미지 폴더에 있지만 JSON에 없는 파일 찾기
missing_in_json = [file for file in image_files if file not in json_image_files]

# 결과 출력
print(f"JSON 파일 내 이미지 개수: {len(json_image_files)}")
print(f"원본 이미지 폴더 내 이미지 개수: {len(image_files)}")
print(f"JSON에 있지만 원본 이미지 폴더에 없는 파일 수: {len(missing_in_images)}")
print(f"원본 이미지 폴더에 있지만 JSON에 없는 파일 수: {len(missing_in_json)}")
print(f"JSON에 있지만 원본 이미지 폴더에 없는 파일: {missing_in_images}")
print(f"원본 이미지 폴더에 있지만 JSON에 없는 파일: {missing_in_json}")
# Out:
# JSON 파일 내 이미지 개수: 16276
# 원본 이미지 폴더 내 이미지 개수: 16276
# JSON에 있지만 원본 이미지 폴더에 없는 파일 수: 0
# 원본 이미지 폴더에 있지만 JSON에 없는 파일 수: 0
# JSON에 있지만 원본 이미지 폴더에 없는 파일: []
# 원본 이미지 폴더에 있지만 JSON에 없는 파일: []

# %%
### 이미지원본이 없는 거 json에서 삭제

import json
import shutil
import os

# JSON 파일 경로
json_file_path = r"C:\Users\LMK\Desktop\merge_10class\patch_merged_class_10.json"
# 백업 파일 경로
backup_folder_path = r"C:\Users\LMK\Desktop\backup"
os.makedirs(backup_folder_path, exist_ok=True)
backup_file_path = os.path.join(backup_folder_path, "merged_class_10_backup.json")

# JSON 파일 백업
try:
    shutil.copy(json_file_path, backup_file_path)
    print(f"원본 JSON 파일의 백업이 '{backup_file_path}'에 저장되었습니다.")
except Exception as e:
    print(f"백업 과정에서 오류가 발생했습니다: {e}")

# JSON 파일 읽기
try:
    with open(json_file_path, 'r') as json_file:
        json_data = json.load(json_file)
except FileNotFoundError:
    print(f"파일을 찾을 수 없습니다: {json_file_path}")
    exit(1)
except json.JSONDecodeError:
    print(f"JSON 파일을 파싱하는 중에 오류가 발생했습니다: {json_file_path}")
    exit(1)

# 제거할 이미지 파일 리스트
missing_in_images = [
    # 파일 목록을 여기에 추가해야 합니다.
    # 예: "image1.jpg", "image2.png"
 '1447846_614(1).jpg', '1448022_614(1).jpg', '1448024_614(1).jpg', '1448027_614(1).jpg', '1448031_614(1).jpg', '1448219_614(1).jpg', '1449809_614(1).jpg', '1449951_614(1).jpg', '1451944_614(1).jpg', '1455805_614(1).jpg', '968982_614.jpg', '969001_614.jpg', '969017_614.jpg', '969434_614.jpg', '969451_614.jpg', '969454_614.jpg', '970392_614.jpg', '970430_614.jpg', '970448_614.jpg', '970748_614.jpg', '970774_614.jpg', '971922_614.jpg', '971941_614.jpg', '971949_614.jpg', '971958_614.jpg', '971960_614.jpg', '971968_614.jpg', '971973_614.jpg', '971991_614.jpg', '971994_614.jpg', '971995_614.jpg', '971996_614.jpg', '972008_614.jpg', '972010_614.jpg', '972157_614.jpg', '972162_614.jpg', '973333_614.jpg', '973336_614.jpg', '973550_614.jpg', '973569_614.jpg', '973574_614.jpg', '973577_614.jpg', '973613_614.jpg', '973615_614.jpg', '973626_614.jpg', '973852_614.jpg', '973916_614.jpg', '973929_614.jpg', '973941_614.jpg', '973951_614.jpg', '974639_614.jpg', '974652_614.jpg', '975125_614.jpg', '975129_614.jpg', '975138_614.jpg', '975145_614.jpg', '975148_614.jpg', '975152_614.jpg', '975158_614.jpg', '975163_614.jpg', '975164_614.jpg', '975168_614.jpg', '975173_614.jpg', '975181_614.jpg', '975188_614.jpg', '975189_614.jpg', '975193_614.jpg', '975194_614.jpg', '975196_614.jpg', '975198_614.jpg', '975202_614.jpg', '975204_614.jpg', '975207_614.jpg', '975208_614.jpg', '975211_614.jpg', '975212_614.jpg', '975214_614.jpg', '975452_614.jpg', '975461_614.jpg', '975463_614.jpg', '975472_614.jpg', '975485_614.jpg', '975497_614.jpg', '975519_614.jpg', '975529_614.jpg', '976111_614.jpg', '976116_614.jpg', '976117_614.jpg', '976123_614.jpg', '976682_614.jpg', '976691_614.jpg', '976699_614.jpg', '977029_614.jpg', '977090_614.jpg', '977091_614.jpg', '977282_614.jpg', '977561_614.jpg', '977762_614.jpg', '977767_614.jpg', '977772_614.jpg', '977777_614.jpg', '977780_614.jpg', '977782_614.jpg', '977788_614.jpg', '977801_614.jpg', '977893_614.jpg', '978119_614.jpg', '978120_614.jpg', '978123_614.jpg', '978710_614.jpg', '978716_614.jpg', '979530_614.jpg', '980067_614.jpg', '980172_614.jpg', '980523_614.jpg', '980533_614.jpg', '980546_614.jpg', '980651_614.jpg', '980706_614.jpg', '980750_614.jpg', '981005_614.jpg', '981049_614.jpg', '981084_614.jpg', '981500_614.jpg', '981504_614.jpg', '981789_614.jpg', '981829_614.jpg', '982145_614.jpg', '985416_614.jpg', '985423_614.jpg', '985437_614.jpg', '985891_614.jpg', '985898_614.jpg', '987256_614.jpg', '987304_614.jpg', '987313_614.jpg', '988010_614.jpg', '988024_614.jpg', '988077_614.jpg', '988116_614.jpg', '988672_614.jpg', '988688_614.jpg', '988696_614.jpg', '988704_614.jpg', '989655_614.jpg', '989827_614.jpg', '989840_614.jpg', '989862_614.jpg', '989871_614.jpg', '989879_614.jpg', '989901_614.jpg', '990024_614.jpg', '990031_614.jpg', '990049_614.jpg', '990067_614.jpg', '990072_614.jpg', '990078_614.jpg', '990187_614.jpg', '990538_614.jpg', '990552_614.jpg', '990554_614.jpg', '992456_614.jpg', '993570_614.jpg', '993964_614.jpg', '993999_614.jpg', '994000_614.jpg', '994145_614.jpg', '994147_614.jpg', '994149_614.jpg', '994247_614.jpg', '994255_614.jpg', '995360_614.jpg', '995371_614.jpg', '995564_614.jpg', '995766_614.jpg', '996060_614.jpg', '997570_614.jpg', '997673_614.jpg', '997678_614.jpg', '997747_614.jpg', '997880_614.jpg', '997944_614.jpg', '998611_614.jpg', '998643_614.jpg', '999137_614.jpg', '999182_614.jpg', '999836_614.jpg']



# JSON 데이터에서 원본 이미지 폴더에 없는 파일 정보 제거
for file in missing_in_images:
    if file in json_data:
        del json_data[file]

# 수정된 JSON 파일을 새 파일로 저장
new_json_file_path = r"C:\Users\LMK\Desktop\merge_10class\merged_class_10_updated.json"
try:
    with open(new_json_file_path, 'w') as new_json_file:
        json.dump(json_data, new_json_file, indent=4)
    print(f"수정된 JSON 파일이 '{new_json_file_path}'에 저장되었습니다.")
except Exception as e:
    print(f"파일을 저장하는 중에 오류가 발생했습니다: {e}")
# Out:
# 원본 JSON 파일의 백업이 'C:\Users\LMK\Desktop\backup\merged_class_10_backup.json'에 저장되었습니다.
# 수정된 JSON 파일이 'C:\Users\LMK\Desktop\merge_10class\merged_class_10_updated.json'에 저장되었습니다.

# %%
### via에서 train, val 추출

# %%
import os
import json
import random
from collections import defaultdict, Counter

# 설정 경로
via_file = r"C:\Users\LMK\Desktop\merge_10class\merged_class_10_updated.json" # VIA 파일 경로
output_folder = r"C:\Users\LMK\Desktop\merge_10class" # 데이터셋 분할 결과 저장 폴더

# 클래스별 목표 개수
target_train_size = 1200
target_val_size = 300
target_test_size = 20  # 테스트 세트 목표 개수

# 클래스별 최대 개수 설정 (실제 데이터 개수 고려)
class_target_sizes = {
    'Road_No_Stopping_or_Parking': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'Crosswalk': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'Road_Speed_Limit_in_School_Zone': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'Road_School_Zone': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'Road_No_Stopping_Zone': {'train': 455, 'val': 100, 'test': 10},
    'Road_No_Parking': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'no_parking': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'school_zone': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'stop': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'fire_hydrant': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size}
}

# 클래스별 이미지 목록
class_images = defaultdict(list)

# VIA 파일 읽기
try:
    with open(via_file, 'r', encoding='utf-8') as f:
        via_data = json.load(f)

    # 이미지별 클래스 수집
    for image_id, image_info in via_data.items():
        regions = image_info.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('label')
            if category:
                class_images[category].append(image_id)
except Exception as e:
    print(f"Error reading VIA file: {e}")

# train, val, test 세트
train_set = set()
val_set = set()
test_set = set()

# 클래스별로 train, val, test로 나누기
for category, images in class_images.items():
    random.shuffle(images)
    target_sizes = class_target_sizes.get(category, {'train': target_train_size, 'val': target_val_size, 'test': target_test_size})
    train_count = min(target_sizes['train'], len(images))  # 데이터 부족 시 최대한 할당
    val_count = min(target_sizes['val'], len(images) - train_count)
    test_count = min(target_sizes['test'], len(images) - train_count - val_count)

    # 현재 카테고리에서 사용될 이미지 필터링
    filtered_images = [img for img in images if img not in train_set and img not in val_set and img not in test_set]

    # train, val, test 세트로 나누기
    train_images = filtered_images[:train_count]
    val_images = filtered_images[train_count:train_count + val_count]
    test_images = filtered_images[train_count + val_count:train_count + val_count + test_count]

    train_set.update(train_images)
    val_set.update(val_images)
    test_set.update(test_images)

# 중복 제거
val_set.difference_update(train_set)
test_set.difference_update(train_set)
test_set.difference_update(val_set)

# 각 세트에 대한 통계 계산
def calculate_statistics(data_set, data_name):
    total_images = len(data_set)
    class_counts = Counter()

    for image_id in data_set:
        image_info = via_data[image_id]
        regions = image_info.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('label')
            if category:
                class_counts[category] += 1

    stats_output = {
        'total_images': total_images,
        'class_counts': dict(class_counts)
    }

    stats_file = os.path.join(output_folder, f'{data_name}_stats.json')
    with open(stats_file, 'w', encoding='utf-8') as f:
        json.dump(stats_output, f, indent=4, ensure_ascii=False)

    print(f"{data_name.capitalize()} set statistics saved to {stats_file}")
    return stats_output

# 통계 출력 및 저장
train_stats = calculate_statistics(train_set, 'train')
val_stats = calculate_statistics(val_set, 'val')
test_stats = calculate_statistics(test_set, 'test')

# 결과 출력
print(f"Train set size: {train_stats['total_images']}")
print(f"Validation set size: {val_stats['total_images']}")
print(f"Test set size: {test_stats['total_images']}")

# 분할된 데이터셋 저장
os.makedirs(output_folder, exist_ok=True)

train_file = os.path.join(output_folder, 'train.json')
val_file = os.path.join(output_folder, 'val.json')
test_file = os.path.join(output_folder, 'test.json')

# 저장할 데이터 생성
train_data = {image_id: via_data[image_id] for image_id in train_set}
val_data = {image_id: via_data[image_id] for image_id in val_set}
test_data = {image_id: via_data[image_id] for image_id in test_set}

try:
    with open(train_file, 'w', encoding='utf-8') as f:
        json.dump(train_data, f, indent=4, ensure_ascii=False)
    with open(val_file, 'w', encoding='utf-8') as f:
        json.dump(val_data, f, indent=4, ensure_ascii=False)
    with open(test_file, 'w', encoding='utf-8') as f:
        json.dump(test_data, f, indent=4, ensure_ascii=False)

    print(f"Train set saved to {train_file}")
    print(f"Validation set saved to {val_file}")
    print(f"Test set saved to {test_file}")
except Exception as e:
    print(f"Error saving dataset: {e}")
# Out:
# Train set statistics saved to C:\Users\LMK\Desktop\merge_10class\train_stats.json
# Val set statistics saved to C:\Users\LMK\Desktop\merge_10class\val_stats.json
# Test set statistics saved to C:\Users\LMK\Desktop\merge_10class\test_stats.json
# Train set size: 8814
# Validation set size: 1637
# Test set size: 97
# Train set saved to C:\Users\LMK\Desktop\merge_10class\train.json
# Validation set saved to C:\Users\LMK\Desktop\merge_10class\val.json
# Test set saved to C:\Users\LMK\Desktop\merge_10class\test.json

# %%
# 중복확인

import json

# 파일 경로 설정
train_via_file = r"C:\Users\LMK\Desktop\merge_10class\train.json"
val_via_file = r"C:\Users\LMK\Desktop\merge_10class\test.json"

# VIA 파일 읽기 함수
def load_via_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# 이미지 파일 이름 추출 함수
def extract_image_names(via_data):
    return set(via_data.keys())

# VIA 파일 읽기
train_via_data = load_via_file(train_via_file)
val_via_data = load_via_file(val_via_file)

# 이미지 파일 이름 목록 추출
train_image_names = extract_image_names(train_via_data)
val_image_names = extract_image_names(val_via_data)

# val 이미지가 train에 있는지 확인
common_images = val_image_names.intersection(train_image_names)
unique_val_images = val_image_names - train_image_names

print(f"Common images found in both 'val' and 'train': {len(common_images)}")
for image in common_images:
    print(f"Image {image} is present in both 'val' and 'train'.")

print(f"Unique images in 'val': {len(unique_val_images)}")
for image in unique_val_images:
    print(f"Image {image} is not present in 'train'.")
# Out:
# Common images found in both 'val' and 'train': 0
# Unique images in 'val': 97
# Image 0302_night_clear_smooth_08900847.png is not present in 'train'.
# Image 0101_light_clear_traffic_06000147.png is not present in 'train'.
# Image 1159573_614.jpg is not present in 'train'.
# Image MP_KSC_020325.jpg is not present in 'train'.
# Image 0302_night_clear_smooth_07022232.png is not present in 'train'.
# Image 0302_night_clear_smooth_07031964.png is not present in 'train'.
# Image 0302_light_rainy_traffic_03000137.png is not present in 'train'.
# Image 1075107_614.jpg is not present in 'train'.
# Image 0102_light_rainy_smooth_11000108.png is not present in 'train'.
# Image MP_SEL_087277.jpg is not present in 'train'.
# Image 0102_light_clear_smooth_06011039.png is not present in 'train'.
# Image MP_SEL_082837.jpg is not present in 'train'.
# Image 0102_light_clear_smooth_06010299.png is not present in 'train'.
# Image 0302_night_clear_smooth_09006251.png is not present in 'train'.
# Image MP_SEL_079831.jpg is not present in 'train'.
# Image 0102_night_clear_smooth_10001325.png is not present in 'train'.
# Image 1587527_614.jpg is not present in 'train'.
# Image 0102_light_clear_smooth_03006847.png is not present in 'train'.
# Image 0102_light_foggy_smooth_07000041.png is not present in 'train'.
# Image 0302_night_clear_smooth_09003346.png is not present in 'train'.
# Image 0302_night_clear_smooth_07016990.png is not present in 'train'.
# Image 0102_night_clear_smooth_10003377.png is not present in 'train'.
# Image 0302_light_clear_smooth_09001402.png is not present in 'train'.
# Image 1866297_614.jpg is not present in 'train'.
# Image 1444312_614.jpg is not present in 'train'.
# Image 0202_light_clear_smooth_08000112.png is not present in 'train'.
# Image 0102_light_rainy_smooth_04000116.png is not present in 'train'.
# Image 0302_night_clear_smooth_07030400.png is not present in 'train'.
# Image 1925435_614.jpg is not present in 'train'.
# Image 0302_night_clear_smooth_07008034.png is not present in 'train'.
# Image 1095134_614.jpg is not present in 'train'.
# Image 0302_light_clear_smooth_11000258.png is not present in 'train'.
# Image 0302_light_clear_smooth_10000190.png is not present in 'train'.
# Image 0102_light_clear_smooth_09008810.png is not present in 'train'.
# Image 0302_night_clear_smooth_03006055.png is not present in 'train'.
# Image MP_KSC_023668.jpg is not present in 'train'.
# Image 0101_light_clear_smooth_09000029.png is not present in 'train'.
# Image 0302_night_clear_smooth_08900280.png is not present in 'train'.
# Image 0102_light_rainy_smooth_06001942.png is not present in 'train'.
# Image 0302_night_clear_smooth_01001575.png is not present in 'train'.
# Image MP_SEL_105619.jpg is not present in 'train'.
# Image 0202_light_clear_smooth_08002835.png is not present in 'train'.
# Image 0102_light_clear_smooth_10005049.png is not present in 'train'.
# Image 0102_night_clear_smooth_01002413.png is not present in 'train'.
# Image 1580143_614.jpg is not present in 'train'.
# Image MP_KSC_008632.jpg is not present in 'train'.
# Image 0402_night_clear_smooth_11000023.png is not present in 'train'.
# Image 0102_light_clear_traffic_10001906.png is not present in 'train'.
# Image MP_SEL_088576.jpg is not present in 'train'.
# Image 0102_night_clear_smooth_11000203.png is not present in 'train'.
# Image 1808438_614.jpg is not present in 'train'.
# Image 0102_light_rainy_smooth_04001214.png is not present in 'train'.
# Image MP_KSC_023090.jpg is not present in 'train'.
# Image 0102_light_clear_smooth_10005764.png is not present in 'train'.
# Image 0302_light_clear_smooth_04000655.png is not present in 'train'.
# Image 0102_light_rainy_smooth_09002208.png is not present in 'train'.
# Image 0402_light_clear_traffic_10000193.png is not present in 'train'.
# Image 966733_614.jpg is not present in 'train'.
# Image 0102_light_clear_smooth_06006111.png is not present in 'train'.
# Image 0202_light_clear_smooth_03000876.png is not present in 'train'.
# Image 1406864_614.jpg is not present in 'train'.
# Image MP_KSC_004340.jpg is not present in 'train'.
# Image 0302_light_clear_smooth_09001152.png is not present in 'train'.
# Image 0102_light_rainy_smooth_04000735.png is not present in 'train'.
# Image 1862514_614.jpg is not present in 'train'.
# Image MP_SEL_074509.jpg is not present in 'train'.
# Image MP_SEL_074728.jpg is not present in 'train'.
# Image 1723091_614.jpg is not present in 'train'.
# Image 0102_night_clear_smooth_09001150.png is not present in 'train'.
# Image MP_SEL_067263.jpg is not present in 'train'.
# Image 894282_614.jpg is not present in 'train'.
# Image 0102_night_clear_smooth_04002449.png is not present in 'train'.
# Image 0302_night_clear_smooth_09003840.png is not present in 'train'.
# Image MP_SEL_088458.jpg is not present in 'train'.
# Image MP_SEL_067015.jpg is not present in 'train'.
# Image 1925446_614.jpg is not present in 'train'.
# Image 0102_light_clear_smooth_09009793.png is not present in 'train'.
# Image 0302_night_clear_smooth_07006125.png is not present in 'train'.
# Image 0102_light_clear_smooth_09006940.png is not present in 'train'.
# Image MP_SEL_082731.jpg is not present in 'train'.
# Image 0102_light_rainy_smooth_09000614.png is not present in 'train'.
# Image 0202_light_clear_smooth_08004744.png is not present in 'train'.
# Image 0102_light_clear_smooth_01005983.png is not present in 'train'.
# Image 1058936_614.jpg is not present in 'train'.
# Image MP_SEL_B003844.jpg is not present in 'train'.
# Image MP_SEL_108135.jpg is not present in 'train'.
# Image 0202_light_clear_smooth_03002539.png is not present in 'train'.
# Image 0402_light_clear_smooth_07001572.png is not present in 'train'.
# Image 0302_light_clear_smooth_03002175.png is not present in 'train'.
# Image 0302_night_clear_smooth_09000988.png is not present in 'train'.
# Image 0302_night_clear_smooth_07005752.png is not present in 'train'.
# Image MP_KSC_020510.jpg is not present in 'train'.
# Image MP_SEL_066340.jpg is not present in 'train'.
# Image 0302_light_rainy_traffic_09900004.png is not present in 'train'.
# Image 1047419_614.jpg is not present in 'train'.
# Image 0102_light_clear_smooth_09006378.png is not present in 'train'.
# Image 0302_night_clear_traffic_03000726.png is not present in 'train'.

# %%
#통계



import os
import json
from collections import defaultdict

# 입력 및 출력 파일 경로 설정
input_via_file = r"C:\Users\LMK\Desktop\merge_10class\val.json" # 변환된 VIA 파일 경로
stats_output_file = r"C:\Users\LMK\Desktop\merge_10class\val_stats.json" # 통계 결과를 저장할 경로

# 카테고리별 통계 초기화
category_stats = defaultdict(int)
total_images = 0

# VIA 파일 읽기
try:
    with open(input_via_file, 'r', encoding='utf-8') as via_file:
        via_data = json.load(via_file)

    # 총 이미지 수 계산
    total_images = len(via_data)

    # 카테고리별 통계 계산
    for image_data in via_data.values():
        regions = image_data.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('label', 'Unknown')  ##label과 CATEGORY
            category_stats[category] += 1

    # 통계 결과 출력
    print(f"Total number of images: {total_images}")
    print("Category statistics:")
    for category, count in category_stats.items():
        print(f"{category}: {count}")

    # 통계 결과를 JSON 파일로 저장
    with open(stats_output_file, 'w', encoding='utf-8') as stats_file:
        json.dump({
            "total_images": total_images,
            "category_statistics": category_stats
        }, stats_file, indent=4, ensure_ascii=False)

    print(f"Statistics saved to {stats_output_file}")

except Exception as e:
    print(f"Error processing VIA file: {e}")
# Out:
# Total number of images: 1722
# Category statistics:
# Road_No_Parking: 450
# fire_hydrant: 240
# Road_No_Stopping_Zone: 97
# Crosswalk: 568
# no_parking: 324
# stop: 309
# Road_No_Stopping_or_Parking: 866
# Road_School_Zone: 142
# Road_Speed_Limit_in_School_Zone: 103
# traffic_lane_yellow_solid: 250
# Statistics saved to C:\Users\LMK\Desktop\merge_10class\val_stats.json

# %% [markdown]
# ### json에 따라 이미지 가져오기

# %%
import os
import json
import shutil

# 설정 경로
train_json_file = r"C:\Users\LMK\Desktop\merge_10class\train.json" # train.json 경로
val_json_file = r"C:\Users\LMK\Desktop\merge_10class\val.json" # val.json 경로
source_folder = r"C:\Users\LMK\Desktop\merge" # 원본 이미지가 있는 폴더
train_output_folder = r"C:\Users\LMK\Desktop\merge_10class\train" # train 이미지 저장할 폴더
val_output_folder = r"C:\Users\LMK\Desktop\merge_10class\val"  # val 이미지 저장할 폴더

# 폴더 생성
os.makedirs(train_output_folder, exist_ok=True)
os.makedirs(val_output_folder, exist_ok=True)

def copy_images(json_file, output_folder):
    try:
        # JSON 파일 읽기
        with open(json_file, 'r', encoding='utf-8') as file:
            data = json.load(file)

        # 이미지 파일 복사
        for image_data in data.values():
            filename = image_data['filename']
            source_path = os.path.join(source_folder, filename)
            destination_path = os.path.join(output_folder, filename)

            if os.path.exists(source_path):
                shutil.copy(source_path, destination_path)
                print(f"Copied {filename} to {output_folder}")
            else:
                print(f"Image file {filename} not found in source folder.")

    except Exception as e:
        print(f"Error processing {json_file}: {e}")

# 이미지 파일 복사
copy_images(train_json_file, train_output_folder)
copy_images(val_json_file, val_output_folder)
# Out:
# Copied MP_KSC_009747.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_10001559.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1812419_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_01002210.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_113874.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1538831_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_076270.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_074957.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1224649_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06011171.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_009753.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_11000480.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_light_clear_smooth_07000998.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B002030.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_081405.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_03001821.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_07000314.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_06000532.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1929097_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_093187.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01004870.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06001175.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_092901.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_09001025.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_03000315.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04005493.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_03000173.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01010301.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_04001798.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07021447.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_traffic_03000629.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_01002230.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_09900525.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07004842.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_088630.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07006251.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 893988_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_076778.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_09009503.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01004576.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_084337.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01008113.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_085531.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_07000522.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07001081.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B003190.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_03002026.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1964726_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01010370.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1196818_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1196591_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1968186_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_09001028.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_11000458.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_smooth_03000057.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_069980.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04004219.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_09008555.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1633254_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04007739.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_010108.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1373403_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1586073_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07001167.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1594439_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04010188.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07017198.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_smooth_09000200.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_09006056.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1762702_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_08900362.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2114056_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_069334.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_087124.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_017757.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_03001443.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_023921.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_07002028.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_081096.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_11000692.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_06001929.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_088682.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_10000512.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_03001870.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_080544.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_020018.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_07002553.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_042519.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07006050.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_077302.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1605489_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_01003574.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07030909.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_08901097.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_rainy_smooth_01000218.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2060713_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_094105.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_103700.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_10000035.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_082146.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01009062.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07010823.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_080705.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0101_light_clear_smooth_08000153.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_11000198.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_009363.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1095122_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_09000191.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_09006515.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1192244_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_03005991.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B000243.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_10001492.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1948972_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1162223_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1717390_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1124294_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B001719.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 910587_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_08000722.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07030667.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_09005479.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_113844.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1569799_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_03001252.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1879434_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2106828_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_021736.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_light_clear_smooth_11000152.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1380668_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1275860_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_04003113.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1235705_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_08000267.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06011368.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_10004258.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_08000657.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_080535.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_11000352.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_traffic_03000526.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07010413.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_075583.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_01003326.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 939061_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_089008.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07003950.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07022768.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_08003359.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1015198_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_008110.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04000259.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1116784_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_086715.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_081431.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_09002374.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1628327_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_016619.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_078091.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1222126_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_018401.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B002089.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_10001667.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_01001217.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1162213_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_03000662.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_105288.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_07000627.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_10005990.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_light_clear_traffic_10000074.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_068048.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_08002000.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01009451.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_03005356.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1339111_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_114253.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_rainy_smooth_07001214.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1556741_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_112070.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_01004241.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_067861.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_019033.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_03004805.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_light_rainy_smooth_03000245.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_10004390.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_074635.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_06000977.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_07000859.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01010081.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1956203_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1761655_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_04000306.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07016371.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_018998.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_10002730.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07017580.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 954774_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07022470.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_06001545.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0101_light_clear_smooth_10000127.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_01001848.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_03006442.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_086986.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_04001122.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1712575_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1945289_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_04004079.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_02003741.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_068033.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_09004660.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04010569.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07017164.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07004210.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_07002792.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_080617.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1538972_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_03004208.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1577382_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_03001029.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_light_clear_smooth_08000969.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_02007341.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_072992.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_109900.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1083919_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1585667_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_019256.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_007830.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_06000468.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_088397.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1713621_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_06002737.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_smooth_03000688.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_03001789.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_03004031.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04007283.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_005403.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_foggy_smooth_07000280.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_06002318.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_10003856.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_075937.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_072827.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_foggy_smooth_07001197.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_08000476.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_07002083.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1750142_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1369513_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_04004350.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_019845.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01005765.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06002738.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_traffic_10000642.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_021980.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1347942_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_06007258.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_light_clear_smooth_08001802.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_03005471.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1373936_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_09001863.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1244156_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_017620.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1033158_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B001842.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_04002134.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_11000097.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_07000925.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_069420.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_006517.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B001278.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_03003810.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_10000884.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_112140.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1745072_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_069690.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_11000421.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_078849.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_008937.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_109858.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_traffic_10001588.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1661352_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_087358.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_005698.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_06002639.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06003835.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1014559_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0101_light_rainy_smooth_11000149.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_03000021.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_018940.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_03000694.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1538790_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_078113.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06012862.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06010689.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_smooth_03001239.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07008131.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_traffic_03000361.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_105269.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1418359_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_09003172.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_10002956.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_03001183.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06002173.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1016682_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1117330_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1607013_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06001206.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07003067.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_108176.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_traffic_10001166.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07007856.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 886667_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 895728_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_11000061.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_081545.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_081959.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06011190.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_08004885.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_07001609.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_traffic_06000856.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_088384.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 973956_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1347287_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_10000899.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_006125.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1703551_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_093630.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_078333.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1616726_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0101_light_clear_smooth_09000437.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_008616.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06008610.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_076707.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06014648.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04002541.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_006019.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_087409.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1060564_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1434042_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01009624.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_09005552.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_traffic_10001179.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_traffic_10000187.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06004043.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_10006397.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_06002313.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_09001358.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_105661.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B001193.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_02008144.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_086841.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2015823_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_11000047.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_03006039.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_traffic_06000490.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_traffic_03000858.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_smooth_03001406.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_023958.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04006597.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1188158_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_09001203.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1568451_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_076737.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07022448.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_076791.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1392014_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_016699.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0101_light_foggy_smooth_06000049.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1585428_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_107772.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_04000390.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2230285_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1251543_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04010466.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_02000567.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2060730_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_09005601.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1588484_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_079875.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1053613_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_006183.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_02005456.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_08004712.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_069194.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07030637.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_09009484.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_018406.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_06001040.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_10000443.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_078119.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04000482.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_02000532.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1717920_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_09002767.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_076830.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_07001741.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_smooth_03000990.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04010449.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_010059.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_light_rainy_smooth_04000087.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_08900808.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 970412_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_04002145.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01002845.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_01004839.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_06001026.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_11002205.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_105378.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 911916_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_03002154.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_08901604.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_066998.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_010058.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_093748.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 927197_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06000976.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_107034.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_01001538.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_088450.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_08000613.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_03002769.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07012553.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07013609.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1351777_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06010516.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07004722.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_10001516.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_03005649.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_074930.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_11000570.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_002540.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_smooth_06000475.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04008803.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B003284.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_11001070.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_09001911.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01003110.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B002870.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07031146.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1023985_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1566322_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1275854_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_03006798.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B003605.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01009394.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_03000469.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06011219.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_068022.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_09000405.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_017558.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07007580.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_foggy_smooth_01000163.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0101_light_clear_smooth_09000001.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07030916.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_08900361.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_smooth_09900013.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_005428.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01007426.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_09006033.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1446552_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2041357_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_07001384.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 891290_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1558460_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_10001318.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_081141.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2040055_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_007479.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07017460.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_04002731.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_smooth_09000241.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2230269_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1064722_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01003423.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_rainy_smooth_07001605.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_020237.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_clear_smooth_09001526.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_005312.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_02004432.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_023710.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07021888.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_traffic_10001114.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1733122_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_076256.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1581165_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_04002603.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_08004019.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_04000289.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_07002369.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_10005591.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_09000619.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1965143_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_03002215.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_113470.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06010783.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_093178.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1650982_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_112524.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07005382.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_078497.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_rainy_smooth_04000567.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_10001359.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_106101.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_09002075.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_03006575.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_traffic_06000095.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_10004213.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_01001090.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_03004028.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_071391.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_light_clear_smooth_08001022.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_foggy_smooth_07000303.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_108009.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1374382_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1181629_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07006055.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_08005020.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_11000290.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_004329.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_02000681.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01004619.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07018682.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_09001855.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_106819.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_107354.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B003680.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_009269.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1631012_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_09002680.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01009259.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_traffic_07000128.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_06000967.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01005333.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_020633.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_08002308.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_110148.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_089640.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1183345_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B001630.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_traffic_04000141.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B003217.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_06000756.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_10001280.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2028281_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_017676.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_03004991.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04005350.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B000739.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1697799_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_09002769.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04009533.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_06001566.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_082916.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01008465.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_07004391.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_01004022.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_079835.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_007178.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1041252_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2249483_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1029934_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_019435.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_018885.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_10001420.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_foggy_smooth_07000287.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2215288_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_04010167.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_light_clear_traffic_03000114.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_09007502.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_08000864.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_02008635.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 891298_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1496149_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01003151.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_01006022.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_02006575.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_light_rainy_traffic_03000222.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_083072.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_113723.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_light_clear_smooth_08001805.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1222336_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_04000063.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_KSC_021503.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1180426_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_01004251.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1083347_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06007431.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_074836.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1620623_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_10001755.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06003707.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_081216.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_rainy_smooth_03005466.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1606353_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_080845.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06002690.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 2013483_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_03001829.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_09005001.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_light_clear_smooth_06008980.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_08001773.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0402_night_clear_smooth_11000435.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_113059.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_09004338.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0102_night_clear_smooth_09000836.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_104089.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 1964772_614.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_B001443.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0302_night_clear_smooth_03005766.png to C:\Users\LMK\Desktop\merge_10class\train
# Copied MP_SEL_085860.jpg to C:\Users\LMK\Desktop\merge_10class\train
# Copied 0202_light_clear_smooth_07000521.png to C:\Users\LMK\Desktop\merge_10class\train
# ...
# Copied 0302_night_clear_smooth_07013078.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 2230580_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_114749.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_light_clear_smooth_06000337.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_foggy_smooth_07001132.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_10006561.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0202_light_clear_smooth_07001162.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 966692_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 966720_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_10001531.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_light_clear_smooth_06002459.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_094676.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1347840_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1062366_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_005511.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_11000050.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1083124_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_073731.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_08001006.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_107632.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_008934.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1129815_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1339092_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_01004372.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_016505.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_rainy_smooth_04000120.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_06001985.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_081326.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_009394.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1007287_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_07004527.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0402_night_clear_smooth_03001816.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_017042.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_068487.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_07001850.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_10005743.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_079359.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 2189167_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_06006963.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_01007200.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_084063.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_071159.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0202_light_clear_smooth_08006095.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_rainy_smooth_11001746.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_017493.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1068387_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_060488.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_traffic_03000286.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_B001702.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_087144.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_light_rainy_smooth_03001165.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0202_light_clear_smooth_01001028.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_traffic_03000297.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_light_rainy_traffic_03000711.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_night_clear_smooth_09003003.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_003760.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_081718.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0402_light_clear_smooth_08000517.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_light_clear_smooth_07005031.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_07003925.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_10000984.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_10006325.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_light_clear_smooth_01001787.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_078324.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_081142.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1024474_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_078984.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_rainy_smooth_04000003.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_024014.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_018612.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 893595_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_07020359.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_07003999.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_01010018.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_rainy_smooth_10000473.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_10001227.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_077667.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_rainy_smooth_11001090.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_07014626.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1323191_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 2207277_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 929151_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_10006285.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_B001636.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_light_rainy_smooth_03001060.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_104653.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_06005643.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1864415_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_113835.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_04001708.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_08002324.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 2062262_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1179244_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_light_rainy_smooth_11000508.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_07002634.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_111100.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_07020040.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_003269.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_009268.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_light_rainy_smooth_11000667.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_08901766.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_B001998.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_B001924.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_112621.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 2073827_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_094653.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_night_clear_smooth_04003484.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0202_light_clear_smooth_04000680.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_01003881.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_01000007.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1644996_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_01009911.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1566725_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_10003408.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_01008103.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_B001496.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_traffic_10001307.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_foggy_smooth_07000454.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_04002438.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_017650.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0202_light_clear_smooth_01001415.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_006662.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_079414.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_04008828.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1244869_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0402_night_clear_smooth_01000912.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_076151.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 1651006_614.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_KSC_008447.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_081552.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_09008190.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_03000296.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_086806.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_03001252.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_10005427.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_113742.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied MP_SEL_B002566.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_06006888.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_light_clear_smooth_01000171.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0102_light_clear_smooth_06011566.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 0302_night_clear_smooth_03006577.png to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3798789.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792339.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3780970.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6934453.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3895313.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3798788.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6979255.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3895293.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6959902.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3780980.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3806635.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792370.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3895291.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3895318.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3909597.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3798818.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792366.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 4056167.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3798793.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6934460.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3909600.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 4056168.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792343.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792337.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3806645.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3895312.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6934462.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792365.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792338.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3909590.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3895299.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6934473.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3798797.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792350.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3781007.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6934469.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 7042209.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3806638.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3780999.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3781003.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 4056165.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3911434.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6940044.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792380.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6934457.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3780975.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3780981.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3806640.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 4056148.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 4056161.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3909582.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6934451.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3909588.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6934482.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 4056158.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6934446.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3909583.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3780987.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3911441.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 4056154.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6960033.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792240.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6940046.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3895302.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6979247.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792329.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3895308.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3895329.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792368.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3780998.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3781005.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3806636.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6959906.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3780967.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3780995.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3909596.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3911427.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3781008.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3806634.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3780963.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3792318.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6960032.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3990196.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 6934555.jpg to C:\Users\LMK\Desktop\merge_10class\val
# Copied 3798817.jpg to C:\Users\LMK\Desktop\merge_10class\val

# %%
### 이미지와 json확인

import os
import json

# 사용자 지정 경로
image_folder_path = r"C:\Users\LMK\Desktop\merge_10class\val"   # 이미지 폴더 경로
json_file_path = r"C:\Users\LMK\Desktop\merge_10class\val.json"   # JSON 파일 경로

# 이미지 파일 목록 가져오기
image_files = [f for f in os.listdir(image_folder_path) if os.path.isfile(os.path.join(image_folder_path, f))]

# JSON 파일 읽기
with open(json_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# JSON 파일에서 이미지 이름 확인
json_image_names = set(item['filename'] for item in data.values())

# JSON에 없는 이미지 파일 목록 추출
missing_images = [img for img in image_files if img not in json_image_names]

# 결과 출력
if missing_images:
    print("JSON 파일에 없는 이미지 파일들:")
    for img in missing_images:
        print(img)
else:
    print("모든 이미지 파일이 JSON 파일에 존재합니다.")
# Out:
# 모든 이미지 파일이 JSON 파일에 존재합니다.

# %%
### via json에서 라벨 이미지정보 추출

import os
import json

# 설정 경로
via_file = r"C:\Users\LMK\Desktop\multiclass_last2\train\via.json"  # VIA 파일 경로
output_file = r"C:\Users\LMK\Desktop\merge_10class\train_filtered_traffic_lane_yellow_solid.json"  # 결과 저장 파일 경로

# 원하는 라벨
desired_label = "traffic_lane_yellow_solid"

# 필터링된 데이터 저장용 딕셔너리
filtered_data = {}

# VIA 파일 읽기
try:
    with open(via_file, 'r', encoding='utf-8') as f:
        via_data = json.load(f)

    # 이미지별로 데이터 필터링
    for image_id, image_info in via_data.items():
        regions = image_info.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('label')
            if category == desired_label:
                filtered_data[image_id] = image_info
                break  # 하나의 라벨만 필요하므로, 일치하는 라벨을 찾으면 중단
except Exception as e:
    print(f"Error reading VIA file: {e}")

# 결과 저장
try:
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(filtered_data, f, indent=4, ensure_ascii=False)
    print(f"Filtered data saved to {output_file}")
except Exception as e:
    print(f"Error saving filtered data: {e}")
# Out:
# Filtered data saved to C:\Users\LMK\Desktop\merge_10class\train_filtered_traffic_lane_yellow_solid.json

# %% [markdown]
# ### 재시각화

# %%
import os
import json
import cv2
import numpy as np

# 입력 및 출력 경로 설정
via_file = r"C:\Users\LMK\Desktop\multi_V8\aug\via_merged.json"  # 변환된 VIA 파일 경로
image_folder = r"C:\Users\LMK\Desktop\multi_V8\aug\train\images"  # 원본 이미지 파일이 들어있는 폴더
output_folder = r"C:\Users\LMK\Desktop\multi_V8\aug\visualized"  # 시각화된 이미지를 저장할 폴더

# 색상 및 폰트 설정
color_mapping = {
    'fire_hydrant': (255, 0, 0),            # 빨간색
    'car': (0, 255, 0),                     # 녹색
    'truck': (0, 0, 255),                   # 파란색
    'stop': (255, 255, 0),                  # 노란색
    'motorcycle': (255, 165, 0),            # 주황색
    'traffic_lane_yellow_solid': (255, 255, 255),  # 흰색
    'school_zone': (255, 0, 255),           # 보라색
    'no_parking': (0, 255, 255),            # 청록색
    'Road_Speed_Limit_in_School_Zone': (128, 128, 0),  # 올리브색
    'Road_School_Zone': (75, 0, 130),       # 인디고색
    'Crosswalk': (0, 128, 128),             # 청록색
    'Road_No_Stopping_Zone': (128, 0, 128), # 자홍색
    'Road_No_Parking': (255, 69, 0),        # 오렌지 레드
    'Road_No_Stopping_or_Parking': (0, 128, 0) # 초록색
}

font_color = (255, 255, 255)  # 흰색
font_scale = 0.5
thickness = 2
font = cv2.FONT_HERSHEY_SIMPLEX

# VIA 파일 읽기
try:
    with open(via_file, 'r', encoding='utf-8') as via_json_file:
        via_data = json.load(via_json_file)

    # 폴더 생성
    os.makedirs(output_folder, exist_ok=True)

    # 이미지 파일 탐색 및 시각화
    for image_key, image_data in via_data.items():
        image_filename = image_data['filename']
        image_path = os.path.join(image_folder, image_filename)

        if not os.path.exists(image_path):
            print(f"Image file not found: {image_path}")
            continue

        # 이미지 읽기
        image = cv2.imread(image_path)
        if image is None:
            print(f"Failed to read image: {image_path}")
            continue

        # 객체 시각화
        regions = image_data.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('label', 'Unknown')
            if category not in color_mapping:
                print(f"Unknown category: {category}")
                continue

            color = color_mapping[category]
            all_points_x = region['shape_attributes'].get('all_points_x', [])
            all_points_y = region['shape_attributes'].get('all_points_y', [])

            if all_points_x and all_points_y and len(all_points_x) == len(all_points_y):
                points = np.array([[x, y] for x, y in zip(all_points_x, all_points_y)], dtype=np.int32)
                points = points.reshape((-1, 1, 2))

                # 폴리곤 그리기
                image = cv2.polylines(image, [points], isClosed=True, color=color, thickness=thickness)

                # 텍스트 표시 (카테고리 이름)
                text_position = (int(all_points_x[0]), int(all_points_y[0]) - 10)
                cv2.putText(image, category, text_position, font, font_scale, font_color, thickness, cv2.LINE_AA)

        # 결과 이미지 저장
        output_image_path = os.path.join(output_folder, image_filename)
        cv2.imwrite(output_image_path, image)
        print(f"Saved visualized image to {output_image_path}")

except Exception as e:
    print(f"Error processing VIA file: {e}")
# Out:
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04006223.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02004111.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_07001366.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07022198.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07018227.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09006817.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_foggy_smooth_07000184.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_11000826.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06010689.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_11000435.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09008067.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02003823.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09004478.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_06001786.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_traffic_08000162.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07002700.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_07003724.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08002927.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04006676.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_07000794.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01001863.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_03002301.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_07000849.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_10000881.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07014667.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_08000310.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_02000532.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07004781.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_07002307.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06012955.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_04000314.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_traffic_06000244.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10000617.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09003633.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_01001693.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_01000300.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_11000643.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_10000324.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07003925.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09008072.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06014243.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_traffic_10000050.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_01003475.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_09000697.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_01001147.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_04002784.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07002647.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_11000425.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_03002202.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06006662.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08001523.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08000373.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_traffic_07001060.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_11000905.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_06001539.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02001979.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_11000412.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02005895.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06008683.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_11001643.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_09000546.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_01003574.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08004762.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10900002.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03001701.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06005872.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_10001332.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09003881.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_01001803.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09002571.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_traffic_10001906.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03004091.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_11000930.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08006035.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_06000532.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02005484.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_rainy_smooth_10000096.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06002743.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_03002259.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_06000946.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_01000673.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_09001461.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_07000203.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_09000503.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06010931.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_smooth_09900013.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_traffic_03000410.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06006794.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_rainy_smooth_03000003.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03006847.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_07000411.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_07001536.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07000111.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_foggy_smooth_07000497.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_07003679.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_07000799.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_09001007.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_01003496.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_06001513.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_03002539.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06014693.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09003834.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_11001082.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06006332.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07002838.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_07002233.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08003777.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_traffic_10000180.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_01003281.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_03000551.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_08002950.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_11000270.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_traffic_03000020.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_01000648.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_07001502.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06010744.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_03001640.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_04001689.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10001015.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_01001726.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_08000231.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_07000835.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07021258.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07005740.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_06002068.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_07001581.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_rainy_smooth_01000278.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_01001596.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_07000464.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06003825.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_01002302.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_04000231.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_07000850.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_09001936.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_01003273.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09006753.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_06000641.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_11002240.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_rainy_smooth_07000289.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_04001130.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_rainy_smooth_09000099.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_rainy_smooth_07002366.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_rainy_smooth_01000285.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07016953.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09009768.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07002645.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02005209.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_01004184.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07002644.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0101_light_rainy_smooth_11000035.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_04000001.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06005847.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09005842.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_11000377.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_03001584.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_08002443.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02000003.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_03005986.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07005005.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07003243.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_07001137.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_smooth_06000431.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04001748.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07002858.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_07002785.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01004125.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09003625.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_04001080.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09002251.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_04000963.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06003808.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_07001039.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_10006119.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07002794.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_11000144.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03005564.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_08900847.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_09001482.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06011566.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03004303.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_03001851.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06008370.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_01001840.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03003891.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07005994.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_rainy_smooth_07000187.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03003995.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09004638.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04004166.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_10002282.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06007636.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09004688.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_11000032.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06011177.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07002455.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08003432.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07015053.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_09001152.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_07000095.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06008624.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_smooth_03000839.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09006637.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04001490.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_04000329.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07006050.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_06000028.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02009111.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_rainy_smooth_01000568.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06011176.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_traffic_03000137.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09003938.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_traffic_03000028.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_10005525.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06008610.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09005869.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_smooth_09000241.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10003865.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01005094.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_07002792.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_02000367.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_03001448.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07022904.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_01000584.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04004141.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07020152.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07022482.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_08000945.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_01003326.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_10002580.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07006254.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_smooth_01000451.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08006255.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06006449.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01002213.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_06000689.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_01001404.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_08900917.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08005063.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_09001417.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_09002353.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06005602.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_08001386.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04005021.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09002895.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10001487.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_03000848.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01007024.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_11001025.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04010485.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09005560.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01008407.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_traffic_10001552.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02003870.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_07002868.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_smooth_11000747.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_11002684.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_traffic_07001012.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_06001505.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_07000207.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01010256.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02006757.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03002258.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08000465.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04010371.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03003278.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_04002709.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_09000756.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09009801.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07005118.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04005450.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09000119.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_06000469.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_04000090.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08000343.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06004137.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07006240.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_04001728.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_10001325.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08005979.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_10000191.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_08001584.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_09001286.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_04001158.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_04002652.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07000488.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_06000571.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06006045.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_01000997.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_rainy_smooth_01000009.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_01000923.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02003366.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_03006330.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_03002105.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_smooth_03000846.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_07000703.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10006709.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07022822.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_11003377.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_09000964.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_traffic_10001977.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_03001775.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07018792.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_smooth_03000060.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01004069.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_08900382.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_11001352.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09004323.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_06001704.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_10000198.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_09001567.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09008555.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07022232.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_06002318.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07020141.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04002605.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09002038.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_07000920.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01009262.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_10004619.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_09000363.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_04000719.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08001987.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10000821.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_03002798.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_03002761.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_10001560.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_traffic_10001959.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_03002895.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_03001630.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01006227.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02001596.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09001501.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_04001214.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_06000298.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07006261.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_02000524.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06002209.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_03002142.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03004801.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01003909.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_traffic_06000162.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09006378.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06007195.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_04001706.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_11000654.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_06001344.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07016990.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_rainy_smooth_01000148.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_rainy_smooth_09000541.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06002388.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_10002351.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02002463.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_04001602.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06013123.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_08901180.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_03001918.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_07001572.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_traffic_10000926.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_09001017.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02004465.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_10001814.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_04002097.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_03001233.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08001524.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_03001664.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_traffic_10000048.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06001957.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_08002893.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_traffic_06000164.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_10001476.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_10000190.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02003879.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_foggy_smooth_07002043.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04008096.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_rainy_smooth_06000035.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_10001960.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04007233.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_01000662.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_06001199.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07001296.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07018495.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_07000940.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_06002540.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_09002603.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_09002581.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06000041.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10000259.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07016819.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02006272.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_smooth_02000653.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_02005498.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_09007533.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_traffic_03000361.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_11002434.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_03004320.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_03001029.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_traffic_03001060.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_07000661.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_09006462.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_light_clear_traffic_02000020.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08006259.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07018469.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06014728.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07003991.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_01003685.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_night_clear_smooth_04004108.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07002401.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04007638.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10001940.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01005489.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_03002087.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_01002022.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06008368.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_08000994.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07001275.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04009058.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08003765.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_08001407.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_01001839.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06003395.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04008631.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_traffic_06000434.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04005567.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_03000573.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_04000281.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_08001776.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_light_clear_smooth_11000152.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_10000908.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06000461.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_rainy_smooth_11000678.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_06002693.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_traffic_06000418.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0202_light_clear_smooth_02000605.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_04010791.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07022319.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10000512.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_07002098.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_07017751.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0402_night_clear_smooth_10001928.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_traffic_10001588.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_10005139.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0102_light_clear_smooth_01005631.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_08901753.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\0302_night_clear_smooth_08001791.png
# ...
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_rainy_smooth_04002668.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_04008543.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_04007230.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_03004322.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_04001654.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07008214.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_light_clear_smooth_03001467.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07007195.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_02008346.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07004421.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_light_clear_smooth_07001587.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_10006271.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_10005815.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07015925.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_06000295.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_light_clear_smooth_06002366.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_08001908.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0402_night_clear_smooth_07001029.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0402_night_clear_smooth_03000570.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_light_clear_smooth_09001720.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_10000983.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_07000613.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_09006445.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_10004767.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_11000689.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_traffic_03000710.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_04007620.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07021359.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_08000309.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_04001195.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_light_clear_smooth_06001524.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_traffic_10001553.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_06003756.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_10001297.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_01003135.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07017783.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07014424.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_rainy_smooth_10000101.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_08006252.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_04001242.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_09001834.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_06002050.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_10002143.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_01001739.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_06001683.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07021372.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0402_light_clear_traffic_10000067.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_09002585.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_08005026.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_rainy_traffic_03000015.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_01003476.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_02003860.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_01003073.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07021444.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0402_night_clear_smooth_03000782.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07000022.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_07001671.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_03005955.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_03005621.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_traffic_03000726.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_08004825.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_03002434.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07004200.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_06001521.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_rainy_smooth_09001675.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_01001968.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07019856.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_03006255.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_06004836.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0402_night_clear_smooth_01001543.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_traffic_10001233.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_10001681.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_03002205.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_07003163.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_03005320.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_06000589.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_09003895.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_10001987.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_light_clear_smooth_09000846.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_09009793.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_11000830.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_traffic_06000032.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_traffic_06000218.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_04001629.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_06011635.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_rainy_smooth_04001150.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_06003059.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_09008784.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_03001785.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_01004121.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_10000807.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_08900629.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_light_clear_smooth_11000258.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_07000863.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07019644.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_06006285.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_07001228.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0402_night_clear_smooth_08000798.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0402_light_clear_smooth_000567.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_07000375.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_rainy_smooth_09000645.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_rainy_traffic_04000125.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_light_rainy_traffic_03000331.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_02004026.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_06006081.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_01000787.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_rainy_smooth_04002620.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_09003669.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_04000996.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_rainy_smooth_10000473.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_10001986.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_rainy_smooth_11001664.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_04004075.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_light_clear_smooth_02000447.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_06011380.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_08001628.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_06013924.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_night_clear_smooth_04000040.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_light_rainy_smooth_03000545.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0402_light_clear_smooth_01000378.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07020140.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0202_light_clear_smooth_08004744.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_rainy_smooth_04002576.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_04005255.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_06001216.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0302_night_clear_smooth_07013801.png
# Saved visualized image to C:\Users\LMK\Desktop\multi_V8\aug\visualized\transformed_2_0102_light_clear_smooth_01006051.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 82
#      80         # 결과 이미지 저장
#      81         output_image_path = os.path.join(output_folder, image_filename)
# ---> 82         cv2.imwrite(output_image_path, image)
#      83         print(f"Saved visualized image to {output_image_path}")
#      85 except Exception as e:
#
# KeyboardInterrupt:

# %%
##카테고리 레이블


import os
import json

# 입력 및 출력 파일 경로 설정
input_via_file = r"C:\Users\LMK\Desktop\6class_via_polyline\via_format_polyline.json" # 변환할 VIA 파일 경로
output_via_file = r"C:\Users\LMK\Desktop\6class_via_polyline\via_format_polyline.json"  # 변환 결과를 저장할 경로

def convert_category_to_label(input_file, output_file):
    try:
        # VIA 파일 읽기
        with open(input_file, 'r', encoding='utf-8') as file:
            via_data = json.load(file)

        # 카테고리를 레이블로 변환
        for image_id, image_data in via_data.items():
            regions = image_data.get('regions', {})
            for region in regions.values():
                region_attributes = region.get('region_attributes', {})
                if 'category' in region_attributes:
                    region_attributes['label'] = region_attributes.pop('category')

        # 변환된 데이터 저장
        with open(output_file, 'w', encoding='utf-8') as file:
            json.dump(via_data, file, indent=4, ensure_ascii=False)

        print(f"Category to label conversion saved to {output_file}")

    except Exception as e:
        print(f"Error processing file {input_file}: {e}")

# 사용 예시
convert_category_to_label(input_via_file, output_via_file)

# %% [markdown]
# ### 이미지 찾기

# %%
import json
import re

# 사용자 지정 경로
json_file_path = r"C:\Users\LMK\Desktop\multiclass_last2\train\train.json"  # 원본 JSON 파일 경로
output_json_path = r"C:\Users\LMK\Desktop\multiclass_last2\train\filtered_train.json"  # 저장할 JSON 파일 경로

# JSON 파일 읽기
with open(json_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 숫자 라벨 확인 함수
def has_numeric_label(region_attributes):
    # 모든 라벨이 숫자인지를 검사
    return any(re.match(r'^\d+$', str(label)) for label in region_attributes.values())

# 숫자 라벨을 가진 이미지를 제외한 데이터 필터링
filtered_data = {}
for key, value in data.items():
    if 'regions' in value:
        filtered_regions = {}
        for region_id, region in value['regions'].items():
            if 'region_attributes' in region and not has_numeric_label(region['region_attributes']):
                filtered_regions[region_id] = region
        if filtered_regions:
            filtered_data[key] = {
                'filename': value['filename'],
                'size': value['size'],
                'regions': filtered_regions
            }

# 수정된 JSON 파일 저장
with open(output_json_path, 'w', encoding='utf-8') as file:
    json.dump(filtered_data, file, indent=4, ensure_ascii=False)

print(f"Filtered data saved to '{output_json_path}'.")

# %%
import os
import json
import shutil

# 설정 경로
via_file = r"C:\Users\LMK\Desktop\dataset_split2\val.json" # VIA 파일 경로
source_folder = r"C:\Users\LMK\Desktop\merge_val"  # 원본 이미지가 있는 폴더
output_folder = r"C:\Users\LMK\Desktop\multiclass\val" # 이미지 저장할 폴더

# 폴더 생성
os.makedirs(output_folder, exist_ok=True)

def copy_via_images(via_file, source_folder, output_folder):
    try:
        # VIA 파일 읽기
        with open(via_file, 'r', encoding='utf-8') as file:
            via_data = json.load(file)

        # 파일 목록 추출 및 복사
        for image_data in via_data.values():
            filename = image_data['filename']
            source_path = os.path.join(source_folder, filename)
            destination_path = os.path.join(output_folder, filename)

            if os.path.exists(source_path):
                shutil.copy(source_path, destination_path)
                print(f"Copied {filename} to {output_folder}")
            else:
                print(f"Image file {filename} not found in source folder.")

    except Exception as e:
        print(f"Error processing {via_file}: {e}")

# 사용 예시
copy_via_images(via_file, source_folder, output_folder)

# %%
## 폴리곤 수정

import json
import numpy as np

# JSON 파일 경로
json_file_path = r"C:\Users\LMK\Desktop\multiclass_last2\val\val.json"
output_json_path = r"C:\Users\LMK\Desktop\multiclass_last2\modified_val.json"

# JSON 파일 읽기
with open(json_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 좌표 정렬 함수
def sort_polygon(points):
    # 중심점을 기준으로 각도를 계산하여 정렬
    center = np.mean(points, axis=0)
    angles = np.arctan2(points[:, 1] - center[1], points[:, 0] - center[0])
    sorted_points = points[np.argsort(angles)]
    return sorted_points

# MP로 시작하는 이미지의 폴리곤 좌표 수정
for image_key, image_data in data.items():
    if image_key.startswith('MP'):
        regions = image_data.get('regions', {})
        for region_id, region in regions.items():
            shape_attributes = region['shape_attributes']
            if 'all_points_x' in shape_attributes and 'all_points_y' in shape_attributes:
                all_points_x = shape_attributes['all_points_x']
                all_points_y = shape_attributes['all_points_y']

                if len(all_points_x) == len(all_points_y) and len(all_points_x) == 4:
                    points = np.array(list(zip(all_points_x, all_points_y)))

                    # 폴리곤 좌표가 교차하는 경우 수정
                    sorted_points = sort_polygon(points)
                    shape_attributes['all_points_x'] = sorted_points[:, 0].tolist()
                    shape_attributes['all_points_y'] = sorted_points[:, 1].tolist()

# 수정된 JSON 파일 저장
with open(output_json_path, 'w', encoding='utf-8') as file:
    json.dump(data, file, indent=4, ensure_ascii=False)

print(f"Modified JSON saved to '{output_json_path}'")

# %%
### json 빈 좌표 검증
import json

# JSON 파일 경로
json_file_path = r"C:\Users\LMK\Desktop\6class_via_polyline\via_format_polyline.json"

# JSON 파일 읽기
with open(json_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 좌표가 없는 데이터를 찾기 위한 함수
def find_empty_coordinates(data):
    images_with_empty_coords = []

    for image_key, image_info in data.items():
        for region_key, region_info in image_info.get('regions', {}).items():
            shape_attributes = region_info.get('shape_attributes', {})
            all_points_x = shape_attributes.get('all_points_x', [])
            all_points_y = shape_attributes.get('all_points_y', [])

            if not all_points_x or not all_points_y:
                images_with_empty_coords.append({
                    'image': image_key,
                    'region': region_key,
                    'filename': image_info.get('filename', 'unknown'),
                    'all_points_x': all_points_x,
                    'all_points_y': all_points_y
                })

    return images_with_empty_coords

# 좌표가 없는 데이터 찾기
empty_coords = find_empty_coordinates(data)

# 결과 출력
if empty_coords:
    print("좌표가 없는 항목을 찾았습니다:")
    for item in empty_coords:
        print(f"이미지: {item['image']}, 파일명: {item['filename']}, 영역: {item['region']}, "
              f"all_points_x: {item['all_points_x']}, all_points_y: {item['all_points_y']}")
else:
    print("모든 항목에 좌표가 있습니다.")

# %%
#빈 좌표 제거

import json

# JSON 파일 경로
json_file_path = r"C:\Users\LMK\Desktop\6class_via_polyline\via_format_polyline.json"

# JSON 파일 읽기
with open(json_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 좌표가 없는 객체를 삭제하는 함수
def remove_empty_coordinates(data):
    for image_key, image_info in data.items():
        if 'regions' in image_info:
            regions = image_info['regions']
            for region_key in list(regions.keys()):  # keys() 리스트를 만들어야 삭제 가능
                shape_attributes = regions[region_key].get('shape_attributes', {})
                all_points_x = shape_attributes.get('all_points_x', [])
                all_points_y = shape_attributes.get('all_points_y', [])

                if not all_points_x or not all_points_y:
                    # 좌표가 없는 객체 삭제
                    del regions[region_key]

            # 만약 모든 regions가 삭제되었다면, 'regions' 키를 제거
            if not regions:
                del image_info['regions']

    return data

# 좌표가 없는 객체 삭제
cleaned_data = remove_empty_coordinates(data)

# 수정된 JSON 파일 저장
cleaned_json_file_path = r"C:\Users\LMK\Desktop\6class_via_polyline\via_format_polyline_cleaned.json"
with open(cleaned_json_file_path, 'w', encoding='utf-8') as file:
    json.dump(cleaned_data, file, ensure_ascii=False, indent=4)

print(f"좌표가 없는 객체가 제거된 JSON 파일이 '{cleaned_json_file_path}'에 저장되었습니다.")

# %%
### 좌표 다각형 검증
import json

# JSON 파일 경로
json_file_path = r'C:/Users/LMK/Desktop/multiclass_last2/val/preprocessed_via.json'

# JSON 파일 읽기
with open(json_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 좌표가 유효한지 확인하는 함수
def is_valid_polygon(points_x, points_y):
    if len(points_x) < 3 or len(points_y) < 3:
        return False
    if len(set(points_x)) < 3 or len(set(points_y)) < 3:
        return False
    return True

# 유효하지 않은 좌표 데이터를 찾기 위한 함수
def find_invalid_coordinates(data):
    invalid_coords = []

    for image_key, image_info in data.items():
        for region_key, region in image_info.get('regions', {}).items():
            shape_attributes = region.get('shape_attributes', {})
            points_x = shape_attributes.get('all_points_x', [])
            points_y = shape_attributes.get('all_points_y', [])

            if not is_valid_polygon(points_x, points_y):
                invalid_coords.append({
                    'image': image_key,
                    'region': region_key,
                    'filename': image_info.get('filename', 'unknown'),
                    'all_points_x': points_x,
                    'all_points_y': points_y
                })

    return invalid_coords

# 유효하지 않은 좌표 데이터 찾기
invalid_coords = find_invalid_coordinates(data)

# 결과 출력
if invalid_coords:
    print("유효하지 않은 좌표 항목을 찾았습니다:")
    for item in invalid_coords:
        print(f"이미지: {item['image']}, 파일명: {item['filename']}, 영역: {item['region']}, "
              f"all_points_x: {item['all_points_x']}, all_points_y: {item['all_points_y']}")
else:
    print("모든 항목이 유효한 좌표를 가지고 있습니다.")

# %%
## 폴리라인 폴리곤 변화 밑 폐곡선

import json
import os

data_path = r"C:/Users/LMK/Desktop/multiclass_last2/val/"
input_json_file = os.path.join(data_path, 'val.json')
output_json_file = os.path.join(data_path, 'preprocessed_via.json')

# 폴리라인을 바운딩 박스로 변환
def polyline_to_bbox(points_x, points_y):
    x_min = min(points_x)
    x_max = max(points_x)
    y_min = min(points_y)
    y_max = max(points_y)
    return x_min, y_min, x_max, y_max

# 데이터 전처리 함수
def preprocess_via_json(via_json):
    for image_id, image_data in via_json.items():
        for region_key, region_data in image_data.get('regions', {}).items():
            shape_attributes = region_data.get('shape_attributes', {})
            if shape_attributes.get('name') == 'polyline':
                all_points_x = shape_attributes.get('all_points_x', [])
                all_points_y = shape_attributes.get('all_points_y', [])

                if len(all_points_x) < 2 or len(all_points_y) < 2:
                    continue  # 유효하지 않은 폴리라인 무시

                # 폴리라인을 바운딩 박스로 변환
                x_min, y_min, x_max, y_max = polyline_to_bbox(all_points_x, all_points_y)

                shape_attributes['name'] = 'polygon'
                shape_attributes['all_points_x'] = [x_min, x_max, x_max, x_min, x_min]
                shape_attributes['all_points_y'] = [y_min, y_min, y_max, y_max, y_min]

    return via_json

# 파일 읽기 및 전처리
with open(input_json_file, 'r') as file:
    via_data = json.load(file)

preprocessed_via_data = preprocess_via_json(via_data)

# 결과 저장
with open(output_json_file, 'w') as file:
    json.dump(preprocessed_via_data, file, indent=2)

print(f"Preprocessed JSON saved to {output_json_file}")

# %% [markdown]
# ### augmentation

# %%
# !pip install albumentations
# Out:
# Requirement already satisfied: albumentations in c:\users\lmk\anaconda3\lib\site-packages (1.4.8)
# Requirement already satisfied: numpy>=1.24.4 in c:\users\lmk\anaconda3\lib\site-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\lmk\anaconda3\lib\site-packages (from albumentations) (1.13.1)
# Requirement already satisfied: scikit-image>=0.21.0 in c:\users\lmk\anaconda3\lib\site-packages (from albumentations) (0.23.2)
# Requirement already satisfied: PyYAML in c:\users\lmk\anaconda3\lib\site-packages (from albumentations) (6.0.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\lmk\anaconda3\lib\site-packages (from albumentations) (4.9.0)
# Requirement already satisfied: scikit-learn>=1.3.2 in c:\users\lmk\anaconda3\lib\site-packages (from albumentations) (1.5.0)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\lmk\anaconda3\lib\site-packages (from albumentations) (2.7.4)
# Requirement already satisfied: albucore>=0.0.4 in c:\users\lmk\anaconda3\lib\site-packages (from albumentations) (0.0.11)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\lmk\anaconda3\lib\site-packages (from albumentations) (4.10.0.82)
# Requirement already satisfied: tomli>=2.0.1 in c:\users\lmk\anaconda3\lib\site-packages (from albucore>=0.0.4->albumentations) (2.0.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\lmk\anaconda3\lib\site-packages (from pydantic>=2.7.0->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\lmk\anaconda3\lib\site-packages (from pydantic>=2.7.0->albumentations) (2.18.4)
# Requirement already satisfied: networkx>=2.8 in c:\users\lmk\anaconda3\lib\site-packages (from scikit-image>=0.21.0->albumentations) (3.2.1)
# Requirement already satisfied: pillow>=9.1 in c:\users\lmk\anaconda3\lib\site-packages (from scikit-image>=0.21.0->albumentations) (10.2.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\lmk\anaconda3\lib\site-packages (from scikit-image>=0.21.0->albumentations) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\lmk\anaconda3\lib\site-packages (from scikit-image>=0.21.0->albumentations) (2024.5.22)
# Requirement already satisfied: packaging>=21 in c:\users\lmk\anaconda3\lib\site-packages (from scikit-image>=0.21.0->albumentations) (23.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\lmk\anaconda3\lib\site-packages (from scikit-image>=0.21.0->albumentations) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lmk\anaconda3\lib\site-packages (from scikit-learn>=1.3.2->albumentations) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lmk\anaconda3\lib\site-packages (from scikit-learn>=1.3.2->albumentations) (3.5.0)

# %%
import os
import json
import random
from collections import defaultdict

# 설정 경로
via_file = r"E:\desktop\6class_merge\aug_schol_zone_crosswalk.json" # VIA 파일 경로
output_folder = r"C:\Users\LMK\Desktop\multi_V8\aug"  # 데이터셋 분할 결과 저장 폴더

# 클래스별 목표 개수
target_train_size = 100
target_val_size = 20

# 클래스별 최대 개수 설정 (실제 데이터 개수 고려)
class_target_sizes = {
    #'Road_No_Stopping_or_Parking': {'train': target_train_size, 'val': target_val_size},
    'Crosswalk': {'train': target_train_size, 'val': target_val_size},
    'Road_Speed_Limit_in_School_Zone': {'train': target_train_size, 'val': target_val_size},
    'Road_School_Zone': {'train': target_train_size, 'val': target_val_size},
    #'Road_No_Stopping_Zone': {'train': 450, 'val': 100},
    #'Road_No_Parking': {'train': target_train_size, 'val': target_val_size}
}

# 클래스별 이미지 목록
class_images = defaultdict(list)

# VIA 파일 읽기
try:
    with open(via_file, 'r', encoding='utf-8') as f:
        via_data = json.load(f)

    # 이미지별 클래스 수집
    for image_id, image_info in via_data.items():
        regions = image_info.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('category')
            if category:
                class_images[category].append(image_id)
except Exception as e:
    print(f"Error reading VIA file: {e}")

# train과 val 세트
train_set = set()
val_set = set()

# 클래스별로 train과 val로 나누기
for category, images in class_images.items():
    random.shuffle(images)
    target_sizes = class_target_sizes.get(category, {'train': target_train_size, 'val': target_val_size})
    train_count = target_sizes['train']
    val_count = target_sizes['val']

    # 현재 카테고리에서 사용될 이미지 필터링
    filtered_images = [img for img in images if img not in train_set and img not in val_set]

    # train과 val 세트로 나누기
    train_images = filtered_images[:train_count]
    val_images = filtered_images[train_count:train_count + val_count]

    train_set.update(train_images)
    val_set.update(val_images)

# 중복 제거
val_set.difference_update(train_set)  # train_set과 중복된 항목 제거

# 결과 출력
print(f"Train set size: {len(train_set)}")
print(f"Validation set size: {len(val_set)}")

# 분할된 데이터셋 저장
os.makedirs(output_folder, exist_ok=True)

train_file = os.path.join(output_folder, 'train.json')
val_file = os.path.join(output_folder, 'val.json')

# 저장할 데이터 생성
train_data = {image_id: via_data[image_id] for image_id in train_set}
val_data = {image_id: via_data[image_id] for image_id in val_set}

try:
    with open(train_file, 'w', encoding='utf-8') as f:
        json.dump(train_data, f, indent=4, ensure_ascii=False)

    with open(val_file, 'w', encoding='utf-8') as f:
        json.dump(val_data, f, indent=4, ensure_ascii=False)

    print(f"Train set saved to {train_file}")
    print(f"Validation set saved to {val_file}")
except Exception as e:
    print(f"Error saving dataset: {e}")
# Out:
# Train set size: 0
# Validation set size: 0
# Train set saved to C:\Users\LMK\Desktop\multi_V8\aug\train.json
# Validation set saved to C:\Users\LMK\Desktop\multi_V8\aug\val.json

# %%
import os
import json
import random
from collections import defaultdict, Counter

# 설정 경로
via_file = r"E:\desktop\6class_merge\aug_schol_zone_crosswalk.json" # VIA 파일 경로
output_folder = r"C:\Users\LMK\Desktop\multi_V8\aug"  # 데이터셋 분할 결과 저장 폴더

# 클래스별 목표 개수
target_train_size = 500
target_val_size = 300
target_test_size = 20  # 테스트 세트 목표 개수

# 클래스별 최대 개수 설정 (실제 데이터 개수 고려)
class_target_sizes = {
    #'Road_No_Stopping_or_Parking': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'Crosswalk': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'Road_Speed_Limit_in_School_Zone': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    'Road_School_Zone': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    #'Road_No_Stopping_Zone': {'train': 455, 'val': 100, 'test': 10},
    #'Road_No_Parking': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    #'no_parking': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    #'school_zone': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    #'stop': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size},
    #'fire_hydrant': {'train': target_train_size, 'val': target_val_size, 'test': target_test_size}
}

# 클래스별 이미지 목록
class_images = defaultdict(list)

# VIA 파일 읽기
try:
    with open(via_file, 'r', encoding='utf-8') as f:
        via_data = json.load(f)

    # 이미지별 클래스 수집
    for image_id, image_info in via_data.items():
        regions = image_info.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('label')
            if category:
                class_images[category].append(image_id)
except Exception as e:
    print(f"Error reading VIA file: {e}")

# train, val, test 세트
train_set = set()
val_set = set()
test_set = set()

# 클래스별로 train, val, test로 나누기
for category, images in class_images.items():
    random.shuffle(images)
    target_sizes = class_target_sizes.get(category, {'train': target_train_size, 'val': target_val_size, 'test': target_test_size})
    train_count = min(target_sizes['train'], len(images))  # 데이터 부족 시 최대한 할당
    val_count = min(target_sizes['val'], len(images) - train_count)
    test_count = min(target_sizes['test'], len(images) - train_count - val_count)

    # 현재 카테고리에서 사용될 이미지 필터링
    filtered_images = [img for img in images if img not in train_set and img not in val_set and img not in test_set]

    # train, val, test 세트로 나누기
    train_images = filtered_images[:train_count]
    val_images = filtered_images[train_count:train_count + val_count]
    test_images = filtered_images[train_count + val_count:train_count + val_count + test_count]

    train_set.update(train_images)
    val_set.update(val_images)
    test_set.update(test_images)

# 중복 제거
val_set.difference_update(train_set)
test_set.difference_update(train_set)
test_set.difference_update(val_set)

# 각 세트에 대한 통계 계산
def calculate_statistics(data_set, data_name):
    total_images = len(data_set)
    class_counts = Counter()

    for image_id in data_set:
        image_info = via_data[image_id]
        regions = image_info.get('regions', {})
        for region in regions.values():
            category = region['region_attributes'].get('label')
            if category:
                class_counts[category] += 1

    stats_output = {
        'total_images': total_images,
        'class_counts': dict(class_counts)
    }

    stats_file = os.path.join(output_folder, f'{data_name}_stats.json')
    with open(stats_file, 'w', encoding='utf-8') as f:
        json.dump(stats_output, f, indent=4, ensure_ascii=False)

    print(f"{data_name.capitalize()} set statistics saved to {stats_file}")
    return stats_output

# 통계 출력 및 저장
train_stats = calculate_statistics(train_set, 'train')
val_stats = calculate_statistics(val_set, 'val')
test_stats = calculate_statistics(test_set, 'test')

# 결과 출력
print(f"Train set size: {train_stats['total_images']}")
print(f"Validation set size: {val_stats['total_images']}")
print(f"Test set size: {test_stats['total_images']}")

# 분할된 데이터셋 저장
os.makedirs(output_folder, exist_ok=True)

train_file = os.path.join(output_folder, 'train.json')
val_file = os.path.join(output_folder, 'val.json')
test_file = os.path.join(output_folder, 'test.json')

# 저장할 데이터 생성
train_data = {image_id: via_data[image_id] for image_id in train_set}
val_data = {image_id: via_data[image_id] for image_id in val_set}
test_data = {image_id: via_data[image_id] for image_id in test_set}

try:
    with open(train_file, 'w', encoding='utf-8') as f:
        json.dump(train_data, f, indent=4, ensure_ascii=False)
    with open(val_file, 'w', encoding='utf-8') as f:
        json.dump(val_data, f, indent=4, ensure_ascii=False)
    with open(test_file, 'w', encoding='utf-8') as f:
        json.dump(test_data, f, indent=4, ensure_ascii=False)

    print(f"Train set saved to {train_file}")
    print(f"Validation set saved to {val_file}")
    print(f"Test set saved to {test_file}")
except Exception as e:
    print(f"Error saving dataset: {e}")
# Out:
# Train set statistics saved to C:\Users\LMK\Desktop\multi_V8\aug\train_stats.json
# Val set statistics saved to C:\Users\LMK\Desktop\multi_V8\aug\val_stats.json
# Test set statistics saved to C:\Users\LMK\Desktop\multi_V8\aug\test_stats.json
# Train set size: 975
# Validation set size: 309
# Test set size: 14
# Train set saved to C:\Users\LMK\Desktop\multi_V8\aug\train.json
# Validation set saved to C:\Users\LMK\Desktop\multi_V8\aug\val.json
# Test set saved to C:\Users\LMK\Desktop\multi_V8\aug\test.json

# %%
import json
import os
import cv2
import numpy as np
import albumentations as A
from albumentations.pytorch import ToTensorV2

def load_via_data(path):
    if os.path.exists(path):
        with open(path, 'r') as f:
            return json.load(f)
    else:
        return {}

def save_transformed_data(data, output_path):
    with open(output_path, 'w') as f:
        json.dump(data, f, indent=4, ensure_ascii=False)

def clamp_keypoints(keypoints, width, height):
    clamped_keypoints = []
    for x, y in keypoints:
        clamped_x = max(0, min(x, width - 1))
        clamped_y = max(0, min(y, height - 1))
        clamped_keypoints.append((clamped_x, clamped_y))
    return clamped_keypoints

# 설정 경로
via_json_path = r"C:\Users\LMK\Desktop\multi_V8\aug\train.json"
output_dir = r"C:\Users\LMK\Desktop\multi_V8\aug\train\trans"
image_dir = r"C:\Users\LMK\Desktop\multi_V8\aug\train"  # 실제 이미지가 저장된 폴더 경로
os.makedirs(output_dir, exist_ok=True)

# JSON 파일 읽기
via_data = load_via_data(via_json_path)

# 데이터 파싱
annotations = []
for key, value in via_data.items():
    filename = value['filename']
    regions = value['regions']
    polygons = []
    labels = []
    for region_key, region_value in regions.items():
        shape_attributes = region_value['shape_attributes']
        all_points_x = shape_attributes['all_points_x']
        all_points_y = shape_attributes['all_points_y']
        polygon = [(x, y) for x, y in zip(all_points_x, all_points_y)]
        polygons.append(polygon)
        labels.append(region_value['region_attributes']['label'])
    annotations.append((filename, polygons, labels))

# 어그멘테이션 정의
transform = A.Compose([
    #A.VerticalFlip(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.2, rotate_limit=45, p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.HueSaturationValue(p=0.2),
    A.Resize(height=640, width=640, p=1.0),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2()
], keypoint_params=A.KeypointParams(format='xy', remove_invisible=False))

# 변형된 이미지 저장 및 JSON 병합
merged_via_data = load_via_data(via_json_path)
all_transformed_data = {}

for iteration in range(3):
    print(f"Iteration {iteration + 1}")
    via_transformed_data = {}

    for filename, polygons, labels in annotations:
        image_path = os.path.join(image_dir, filename)

        if not os.path.exists(image_path):
            print(f"Error: File '{image_path}' does not exist.")
            continue

        image = cv2.imread(image_path)
        if image is None:
            print(f"Error: Failed to read the image '{image_path}'.")
            continue

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        height, width, _ = image.shape

        keypoints = [point for polygon in polygons for point in polygon]
        clamped_keypoints = clamp_keypoints(keypoints, width, height)

        transformed = transform(image=image, keypoints=clamped_keypoints)
        transformed_image = transformed['image']
        transformed_keypoints = transformed['keypoints']

        transformed_polygons = []
        index = 0
        for polygon in polygons:
            num_points = len(polygon)
            transformed_polygon = transformed_keypoints[index:index + num_points]
            transformed_polygons.append(transformed_polygon)
            index += num_points

        transformed_filename = f"transformed_{iteration + 1}_{filename}"
        transformed_image_path = os.path.join(output_dir, transformed_filename)

        transformed_image_np = transformed_image.permute(1, 2, 0).cpu().numpy()
        transformed_image_np = np.clip(transformed_image_np * 255, 0, 255).astype(np.uint8)
        transformed_image_np = cv2.cvtColor(transformed_image_np, cv2.COLOR_RGB2BGR)
        cv2.imwrite(transformed_image_path, transformed_image_np)

        new_polygons = [{'all_points_x': [int(x) for x, y in polygon], 'all_points_y': [int(y) for x, y in polygon]} for polygon in transformed_polygons]

        new_key = f"{filename}_transformed_{iteration + 1}"
        via_transformed_data[new_key] = {
            'filename': transformed_filename,
            'regions': {str(i): {'shape_attributes': new_polygons[i], 'region_attributes': {'label': labels[i]}} for i in range(len(new_polygons))}
        }

    # 각 반복마다 변환된 데이터를 병합 데이터에 추가
    all_transformed_data.update(via_transformed_data)

    # 각 반복마다 변환된 데이터 저장
    transformed_output_path = os.path.join(output_dir, f'via_transformed_{iteration + 1}.json')
    save_transformed_data(via_transformed_data, transformed_output_path)

    print(f"Total processed images in iteration {iteration + 1}: {len(via_transformed_data)}")

# 모든 변환된 데이터를 병합
merged_via_data.update(all_transformed_data)

merged_output_path = os.path.join(output_dir, 'via_merged.json')
save_transformed_data(merged_via_data, merged_output_path)

print(f"Merged transformed data saved to {merged_output_path}")
# Out:
# Iteration 1
# Total processed images in iteration 1: 975
# Iteration 2
# Total processed images in iteration 2: 975
# Iteration 3
# Total processed images in iteration 3: 975
# Merged transformed data saved to C:\Users\LMK\Desktop\multi_V8\aug\train\trans\via_merged.json

# %%
import os
import json
import shutil

# 설정 경로
train_json_file = r"C:\Users\LMK\Desktop\multi_V8\aug\train.json" # train.json 경로
val_json_file = r"C:\Users\LMK\Desktop\multi_V8\aug\val.json" # val.json 경로
source_folder = r"E:\desktop\merge" # 원본 이미지가 있는 폴더
train_output_folder = r"C:\Users\LMK\Desktop\multi_V8\aug\train" # train 이미지 저장할 폴더
val_output_folder = r"C:\Users\LMK\Desktop\multi_V8\aug\val"  # val 이미지 저장할 폴더

# 폴더 생성
os.makedirs(train_output_folder, exist_ok=True)
os.makedirs(val_output_folder, exist_ok=True)

def copy_images(json_file, output_folder):
    try:
        # JSON 파일 읽기
        with open(json_file, 'r', encoding='utf-8') as file:
            data = json.load(file)

        # 이미지 파일 복사
        for image_data in data.values():
            filename = image_data['filename']
            source_path = os.path.join(source_folder, filename)
            destination_path = os.path.join(output_folder, filename)

            if os.path.exists(source_path):
                shutil.copy(source_path, destination_path)
                print(f"Copied {filename} to {output_folder}")
            else:
                print(f"Image file {filename} not found in source folder.")

    except Exception as e:
        print(f"Error processing {json_file}: {e}")

# 이미지 파일 복사
copy_images(train_json_file, train_output_folder)
copy_images(val_json_file, val_output_folder)
# Out:
# Copied 0102_light_clear_smooth_04006223.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02004111.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_07001366.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07022198.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07018227.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09006817.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_foggy_smooth_07000184.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_11000826.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06010689.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_11000435.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09008067.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02003823.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09004478.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_06001786.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_traffic_08000162.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07002700.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_07003724.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08002927.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04006676.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07000794.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01001863.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03002301.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07000849.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_10000881.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07014667.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_08000310.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_02000532.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07004781.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_07002307.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06012955.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_04000314.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_traffic_06000244.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10000617.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09003633.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_01001693.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_01000300.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_11000643.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_10000324.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07003925.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09008072.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06014243.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_traffic_10000050.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_01003475.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_09000697.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_01001147.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04002784.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07002647.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_11000425.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03002202.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06006662.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08001523.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08000373.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_traffic_07001060.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_11000905.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_06001539.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02001979.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_11000412.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02005895.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06008683.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_11001643.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_09000546.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_01003574.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08004762.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10900002.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03001701.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06005872.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_10001332.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09003881.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_01001803.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09002571.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_traffic_10001906.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03004091.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_11000930.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08006035.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_06000532.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02005484.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_rainy_smooth_10000096.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06002743.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03002259.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_06000946.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_01000673.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_09001461.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07000203.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_09000503.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06010931.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_smooth_09900013.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_traffic_03000410.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06006794.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_rainy_smooth_03000003.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03006847.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07000411.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_07001536.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07000111.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_foggy_smooth_07000497.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_07003679.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07000799.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_09001007.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_01003496.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_06001513.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03002539.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06014693.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09003834.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_11001082.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06006332.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07002838.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_07002233.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08003777.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_traffic_10000180.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_01003281.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_03000551.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_08002950.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_11000270.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_traffic_03000020.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_01000648.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_07001502.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06010744.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03001640.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04001689.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10001015.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_01001726.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_08000231.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_07000835.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07021258.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07005740.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_06002068.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_07001581.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_rainy_smooth_01000278.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_01001596.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07000464.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06003825.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_01002302.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04000231.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07000850.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_09001936.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_01003273.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09006753.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_06000641.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_11002240.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_rainy_smooth_07000289.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04001130.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_rainy_smooth_09000099.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_rainy_smooth_07002366.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_rainy_smooth_01000285.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07016953.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09009768.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07002645.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02005209.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_01004184.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07002644.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0101_light_rainy_smooth_11000035.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_04000001.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06005847.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09005842.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_11000377.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03001584.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_08002443.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02000003.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_03005986.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07005005.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07003243.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07001137.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_smooth_06000431.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04001748.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07002858.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_07002785.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01004125.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09003625.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_04001080.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09002251.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_04000963.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06003808.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07001039.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10006119.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07002794.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_11000144.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03005564.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08900847.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_09001482.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06011566.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03004303.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_03001851.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06008370.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_01001840.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03003891.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07005994.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_rainy_smooth_07000187.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03003995.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09004638.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04004166.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_10002282.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06007636.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09004688.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_11000032.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06011177.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07002455.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08003432.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07015053.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_09001152.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_07000095.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06008624.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_smooth_03000839.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09006637.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04001490.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_04000329.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07006050.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_06000028.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02009111.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_rainy_smooth_01000568.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06011176.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_traffic_03000137.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09003938.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_traffic_03000028.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10005525.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06008610.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09005869.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_smooth_09000241.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10003865.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01005094.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_07002792.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_02000367.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_03001448.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07022904.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_01000584.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04004141.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07020152.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07022482.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08000945.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_01003326.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_10002580.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07006254.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_smooth_01000451.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08006255.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06006449.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01002213.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_06000689.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_01001404.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08900917.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08005063.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_09001417.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_09002353.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06005602.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_08001386.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04005021.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09002895.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10001487.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_03000848.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01007024.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_11001025.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04010485.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09005560.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01008407.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_traffic_10001552.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02003870.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_07002868.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_smooth_11000747.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_11002684.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_traffic_07001012.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_06001505.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_07000207.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01010256.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02006757.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03002258.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08000465.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04010371.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03003278.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04002709.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_09000756.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09009801.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07005118.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04005450.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09000119.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_06000469.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_04000090.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08000343.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06004137.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07006240.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_04001728.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_10001325.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08005979.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_10000191.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08001584.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_09001286.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04001158.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04002652.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07000488.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_06000571.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06006045.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_01000997.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_rainy_smooth_01000009.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_01000923.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02003366.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_03006330.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03002105.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_smooth_03000846.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_07000703.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10006709.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07022822.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_11003377.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_09000964.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_traffic_10001977.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03001775.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07018792.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_smooth_03000060.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01004069.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08900382.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_11001352.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09004323.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_06001704.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_10000198.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_09001567.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09008555.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07022232.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_06002318.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07020141.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04002605.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09002038.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_07000920.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01009262.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10004619.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_09000363.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_04000719.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08001987.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10000821.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_03002798.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_03002761.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_10001560.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_traffic_10001959.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_03002895.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_03001630.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01006227.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02001596.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09001501.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04001214.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_06000298.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07006261.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_02000524.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06002209.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03002142.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03004801.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01003909.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_traffic_06000162.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09006378.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06007195.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_04001706.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_11000654.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_06001344.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07016990.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_rainy_smooth_01000148.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_rainy_smooth_09000541.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06002388.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10002351.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02002463.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_04001602.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06013123.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08901180.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03001918.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_07001572.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_traffic_10000926.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_09001017.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02004465.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_10001814.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04002097.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_03001233.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08001524.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_03001664.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_traffic_10000048.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06001957.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_08002893.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_traffic_06000164.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10001476.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_10000190.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02003879.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_foggy_smooth_07002043.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04008096.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_rainy_smooth_06000035.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10001960.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04007233.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_01000662.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_06001199.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07001296.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07018495.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_07000940.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06002540.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_09002603.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_09002581.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06000041.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10000259.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07016819.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02006272.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_02000653.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02005498.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09007533.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_traffic_03000361.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_11002434.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_03004320.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_03001029.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_traffic_03001060.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_07000661.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09006462.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_traffic_02000020.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08006259.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07018469.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06014728.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07003991.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_01003685.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_04004108.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07002401.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04007638.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10001940.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01005489.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03002087.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_01002022.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06008368.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_08000994.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07001275.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04009058.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08003765.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08001407.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_01001839.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06003395.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04008631.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_traffic_06000434.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04005567.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_03000573.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_04000281.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08001776.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_11000152.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_10000908.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06000461.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_11000678.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06002693.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_traffic_06000418.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_02000605.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04010791.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07022319.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10000512.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07002098.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07017751.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_10001928.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_traffic_10001588.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10005139.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01005631.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08901753.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08001791.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04002375.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01004773.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02002454.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06007073.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10004650.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07014240.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04007337.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06007323.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06011187.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_traffic_04000109.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01001464.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_foggy_smooth_08000018.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02003521.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_rainy_smooth_01000218.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_03002117.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_03002810.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04007465.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_06003134.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08004741.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07003239.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09002580.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07000829.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_11000031.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_04003104.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_rainy_smooth_07000901.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_08000055.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_01002204.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07004842.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_11000543.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06011082.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10005491.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_01001402.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08004345.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07017537.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07017165.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_01001903.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08006124.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_03000612.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_07003309.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08000902.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10003711.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_07002782.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04001416.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07023228.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04006742.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02006218.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09005968.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10001511.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10006374.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07002830.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_traffic_03000673.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_10000288.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_03002956.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_traffic_10000072.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_04001490.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09008837.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_06012837.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10006121.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_000269.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07030683.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07001156.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10001708.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_08003881.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_01002224.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_10002012.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07022784.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_09001050.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04002842.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10006536.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07014626.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04008501.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_10000298.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_11001498.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07006103.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07016804.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04008978.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_night_clear_smooth_09001150.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_rainy_smooth_07000495.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_06003867.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08001204.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_night_clear_smooth_09000220.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08001886.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_07000673.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09002505.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_09007268.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_07001909.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_09000171.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_03002026.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_08900727.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04003362.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07005990.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_11002490.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10002822.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_07021345.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0202_light_clear_smooth_07001182.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_10000624.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_rainy_smooth_06001734.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_10000378.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_01010431.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_traffic_10000963.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_07000835.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_night_clear_smooth_09003346.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0402_light_clear_smooth_07000919.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_08000098.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0302_light_clear_smooth_09000871.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_04004231.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# Copied 0102_light_clear_smooth_02006211.png to C:\Users\LMK\Desktop\multi_V8\aug\train
# ...
# Copied 0102_light_clear_smooth_08000528.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_rainy_smooth_07002495.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06001356.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_light_clear_smooth_08001382.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_09006129.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_01005184.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_09007502.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_06000790.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_09005186.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_03001674.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06003682.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07022845.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_07001067.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06000927.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_11001458.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_09005388.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_traffic_09000023.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_03001757.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_traffic_10000488.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_10006437.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_06002929.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_03001439.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_09007749.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_10004164.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07032310.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_06001110.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_03001351.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_01004318.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_08000953.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_06002782.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_rainy_traffic_04000059.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_rainy_smooth_06000582.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_traffic_10000236.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_02006730.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_smooth_03000046.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_light_clear_smooth_06000390.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_rainy_smooth_03001367.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_11000492.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06010593.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_08000051.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_light_clear_smooth_03000641.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_10005049.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_rainy_smooth_10000291.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06000054.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_06001511.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07016952.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07019933.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_10006301.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_01004879.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_02008118.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07020535.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_rainy_smooth_09000091.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06002973.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_04003443.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_01001852.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_06002383.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_foggy_smooth_06000020.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_03001451.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_01004480.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_01003387.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_03005733.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_smooth_01000645.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_01005235.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_03002820.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_01000186.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_07000593.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_night_clear_smooth_11000272.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_night_clear_smooth_01003562.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_light_rainy_smooth_03000188.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06011219.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_02000978.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_10006389.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_01009846.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_09002545.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_10006142.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_01002230.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_02002919.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06000976.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_03002695.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_08001265.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_10001472.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06008677.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_night_clear_smooth_07000346.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_02007833.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_08005072.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_10005609.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_light_clear_smooth_03000582.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07011917.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_night_clear_smooth_06000344.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_night_clear_smooth_01003653.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07017918.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07000771.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_09006404.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_03002693.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_01004430.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_09001006.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07002456.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_07001307.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_03001850.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07003949.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07000815.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_08000864.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_night_clear_smooth_07000232.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07023086.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_04004705.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_10001462.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_rainy_smooth_04002712.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_night_clear_smooth_01004637.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_traffic_02000190.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_04008773.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_smooth_10001953.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_10005764.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_09005859.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_smooth_07000875.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_01004489.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_smooth_07000786.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_night_clear_smooth_06000888.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_light_clear_smooth_08000998.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_03001709.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_04003465.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07001995.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_rainy_smooth_10000142.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_03002743.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_11002476.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_rainy_smooth_01000122.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_03001663.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_foggy_smooth_07001196.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_traffic_07000417.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_rainy_smooth_09002175.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_02000203.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_smooth_09000977.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_rainy_smooth_06000915.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_04008582.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_07003659.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_02006183.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_04008743.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_01003182.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_rainy_smooth_04002056.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_light_clear_smooth_06000330.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07000035.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07008034.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_01003494.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_08001607.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07002094.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_01004515.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_04002493.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_01007031.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_rainy_smooth_07002354.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_rainy_smooth_06000122.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_04003916.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_smooth_07003425.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_02001896.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_06000525.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_08006115.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07005392.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_08901672.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06013329.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_smooth_09001050.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_rainy_smooth_11001717.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07021248.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_10005045.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_03002217.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07022452.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06010652.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_06000706.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_02002525.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_09005310.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07005768.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_07002810.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_08004052.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07004911.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_foggy_smooth_07000246.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_07001297.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_traffic_04000270.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_rainy_smooth_09000146.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_night_clear_smooth_01004837.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_light_clear_smooth_03000726.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_smooth_01000959.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_04002950.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_04000516.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_07002329.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_06005186.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0102_light_clear_smooth_10004034.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_smooth_06000792.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_light_clear_smooth_03000595.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0402_night_clear_traffic_06000139.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0202_light_clear_smooth_08005157.png to C:\Users\LMK\Desktop\multi_V8\aug\val
# Copied 0302_light_clear_traffic_06000487.png to C:\Users\LMK\Desktop\multi_V8\aug\val
